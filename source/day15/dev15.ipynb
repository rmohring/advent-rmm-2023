# %%
import numpy as np

fh = open("input15-1.dat")
#fh = open("test.dat")

rows = fh.readlines()[0].strip("\n")
#rows = "rn=1,cm-,qp=3,cm=2,qp-,pc=4,ot=9,ab=5,pc-,pc=6,ot=7"

# %%
groups = rows.split(",")
gvals = [[ord(x) for x in grp] for grp in groups]

# %%
groups[1],gvals[1]
# Out:
# ('sf=3', [115, 102, 61, 51])

# %%
instructions = []

for g in groups:
    curr = 0
    if "=" in g:
        (label, fl) = g.split("=")
    else:
        (label, fl) = (g[:-1], -1)    
    gvals = [ord(x) for x in label]
    for a in gvals:
        curr = ((curr + a) * 17) % 256
    instructions.append( (curr, label, fl) )

# %%
len(instructions)
# Out:
# 4000

# %%
for x in instructions:
    print(x)
# Out:
# (99, 'ndvk', -1)
# (153, 'sf', '3')
# (112, 'jf', -1)
# (62, 'hv', '9')
# (51, 'rmtp', '4')
# (135, 'tc', '1')
# (60, 'xrr', -1)
# (70, 'xjd', '5')
# (102, 'rlgq', '8')
# (180, 'jxnd', -1)
# (53, 'qd', -1)
# (226, 'hxb', '4')
# (241, 'bgh', '7')
# (102, 'rlgq', '2')
# (103, 'kdll', '8')
# (236, 'tx', -1)
# (176, 'tpgzk', '8')
# (240, 'rvh', -1)
# (30, 'gg', -1)
# (237, 'ktlshg', -1)
# (101, 'mrzl', -1)
# (137, 'qlxt', '7')
# (254, 'shc', -1)
# (21, 'nlk', '2')
# (223, 'qn', -1)
# (174, 'zsq', '4')
# (102, 'cs', '3')
# (37, 'qblf', -1)
# (86, 'rd', '7')
# (101, 'rkjn', -1)
# (75, 'gzsvq', '5')
# (180, 'jxnd', -1)
# (136, 'rv', '3')
# (195, 'kx', '7')
# (206, 'qm', -1)
# (181, 'lpgr', '5')
# (11, 'kld', -1)
# (137, 'cf', -1)
# (117, 'tq', -1)
# (187, 'sh', -1)
# (29, 'vqtr', '6')
# (3, 'qdhf', '1')
# (172, 'lrn', -1)
# (41, 'xlmx', -1)
# (20, 'vlr', -1)
# (163, 'tkd', -1)
# (120, 'vnt', '9')
# (85, 'sb', '3')
# (129, 'gtv', -1)
# (174, 'bff', '9')
# (123, 'qgc', '2')
# (197, 'mxp', '6')
# (200, 'vr', -1)
# (1, 'sdz', -1)
# (244, 'xvf', -1)
# (215, 'djlm', '2')
# (242, 'msbjv', '4')
# (54, 'xxf', '8')
# (108, 'jvtx', -1)
# (101, 'mrzl', -1)
# (231, 'jm', '1')
# (1, 'sdz', '8')
# (155, 'gnrt', '5')
# (236, 'mskmt', '4')
# (68, 'rhj', '3')
# (218, 'ft', '3')
# (154, 'cg', '1')
# (178, 'tfvb', '2')
# (142, 'zdrpn', -1)
# (33, 'sn', -1)
# (170, 'kgh', '4')
# (86, 'rd', '5')
# (104, 'px', '6')
# (47, 'gh', -1)
# (178, 'tfvb', '5')
# (242, 'qsxf', '5')
# (67, 'fvgqlc', '2')
# (70, 'pv', -1)
# (188, 'fpf', -1)
# (125, 'mp', -1)
# (42, 'zp', '7')
# (218, 'lvx', -1)
# (13, 'gbt', -1)
# (149, 'dlmfb', -1)
# (75, 'gzsvq', -1)
# (162, 'vjvl', '5')
# (242, 'msbjv', '1')
# (206, 'qm', '3')
# (6, 'qpkz', '7')
# (174, 'vll', -1)
# (173, 'bkhdt', '5')
# (250, 'xb', '4')
# (145, 'brscg', '4')
# (158, 'cbfc', -1)
# (22, 'nfzh', -1)
# (246, 'qrs', '1')
# (117, 'shj', -1)
# (224, 'pp', -1)
# (127, 'rpm', '9')
# (181, 'lpgr', -1)
# (153, 'cv', '1')
# (175, 'jdq', '3')
# (57, 'tmx', '5')
# (214, 'hsk', -1)
# (85, 'sb', '5')
# (5, 'kpz', -1)
# (145, 'brscg', '8')
# (202, 'fd', -1)
# (164, 'jkhg', -1)
# (70, 'pv', -1)
# (146, 'rnr', -1)
# (153, 'sf', '3')
# (132, 'gm', '8')
# (6, 'lz', -1)
# (166, 'crmd', -1)
# (161, 'jvdm', -1)
# (142, 'zdrpn', -1)
# (107, 'cbv', -1)
# (123, 'gjz', -1)
# (188, 'fpf', -1)
# (135, 'tc', -1)
# (242, 'kzbmn', '5')
# (239, 'tcx', '3')
# (26, 'tkk', '9')
# (52, 'hzr', -1)
# (86, 'knjsp', '4')
# (202, 'fd', -1)
# (171, 'ch', '2')
# (62, 'zmg', -1)
# (213, 'zkhx', '8')
# (242, 'kzbmn', '4')
# (197, 'pcr', '8')
# (193, 'nvxng', '6')
# (13, 'zkh', -1)
# (130, 'xj', '8')
# (223, 'qn', '6')
# (29, 'gv', -1)
# (81, 'vk', -1)
# (0, 'pld', -1)
# (78, 'nvj', -1)
# (81, 'vk', '7')
# (20, 'pd', -1)
# (43, 'lkt', '8')
# (102, 'mxnc', '1')
# (153, 'sf', -1)
# (236, 'bvfn', -1)
# (28, 'xzmm', -1)
# (205, 'ldm', -1)
# (65, 'xnk', '4')
# (7, 'tsld', '2')
# (30, 'vh', '9')
# (130, 'xj', -1)
# (37, 'grgrps', '2')
# (104, 'px', '8')
# (205, 'tcv', -1)
# (205, 'bhs', '8')
# (42, 'hglmnt', '9')
# (28, 'mhg', -1)
# (214, 'hsk', '3')
# (52, 'drtj', -1)
# (249, 'zmr', -1)
# (236, 'tx', -1)
# (37, 'grgrps', '1')
# (7, 'tsld', '2')
# (97, 'gz', -1)
# (142, 'mq', '7')
# (144, 'jbd', -1)
# (37, 'qgm', -1)
# (122, 'fnf', -1)
# (194, 'xqsv', '5')
# (215, 'nvc', '1')
# (120, 'vnt', -1)
# (92, 'kzmhkg', -1)
# (197, 'mxp', -1)
# (228, 'lnj', -1)
# (93, 'zs', '7')
# (153, 'vpc', -1)
# (165, 'hql', '2')
# (135, 'tc', -1)
# (98, 'gk', -1)
# (175, 'jdq', '9')
# (162, 'mkffn', '8')
# (240, 'rvh', '2')
# (163, 'tkd', '3')
# (102, 'rlgq', '2')
# (26, 'dlj', -1)
# (31, 'bkr', -1)
# (144, 'vxb', -1)
# (74, 'gpkh', -1)
# (28, 'xzmm', -1)
# (8, 'ggj', '8')
# (115, 'gl', -1)
# (126, 'dvhvf', -1)
# (135, 'qkk', -1)
# (70, 'pv', '7')
# (14, 'jjz', -1)
# (227, 'fkr', '9')
# (60, 'fhn', '4')
# (90, 'btd', '2')
# (255, 'tsx', -1)
# (28, 'xd', '3')
# (240, 'rvh', '2')
# (57, 'ml', -1)
# (101, 'vxjjs', '4')
# (217, 'grp', -1)
# (205, 'dbznbm', -1)
# (193, 'nkh', '7')
# (62, 'zmg', '1')
# (189, 'bk', -1)
# (37, 'brqld', -1)
# (252, 'bbph', -1)
# (162, 'jx', '8')
# (150, 'rpqs', '8')
# (165, 'hql', '9')
# (175, 'jdq', -1)
# (126, 'dvhvf', '5')
# (89, 'gkg', '3')
# (188, 'pkq', '3')
# (221, 'sj', '8')
# (34, 'dscx', -1)
# (85, 'sb', -1)
# (202, 'tldf', -1)
# (246, 'qrs', -1)
# (51, 'rq', -1)
# (241, 'cjvn', '3')
# (121, 'sksgsn', -1)
# (249, 'zmr', '6')
# (98, 'jdqmf', -1)
# (8, 'km', '2')
# (26, 'tkk', '7')
# (37, 'grgrps', -1)
# (0, 'pld', -1)
# (171, 'fjjtm', -1)
# (114, 'hj', -1)
# (5, 'kpz', '8')
# (94, 'lzx', -1)
# (247, 'kl', -1)
# (56, 'ttcmzv', -1)
# (99, 'ndvk', '5')
# (147, 'gth', '3')
# (2, 'mqfxv', -1)
# (142, 'zdrpn', '8')
# (237, 'ktlshg', -1)
# (94, 'zd', '6')
# (28, 'cpqx', -1)
# (231, 'jm', -1)
# (145, 'kf', -1)
# (86, 'rd', '3')
# (242, 'kzbmn', '9')
# (6, 'grgf', -1)
# (103, 'dsp', '7')
# (103, 'dsp', -1)
# (75, 'gzsvq', -1)
# (204, 'dh', '9')
# (108, 'jvtx', '7')
# (112, 'xx', -1)
# (85, 'kvd', '8')
# (175, 'mnd', -1)
# (162, 'mkffn', -1)
# (152, 'td', -1)
# (127, 'rpm', '7')
# (94, 'lzx', -1)
# (174, 'zsq', '2')
# (136, 'rv', -1)
# (237, 'sz', '2')
# (132, 'gm', '8')
# (145, 'gvd', '2')
# (81, 'vk', -1)
# (144, 'ld', '5')
# (86, 'rd', '9')
# (201, 'fsp', '5')
# (174, 'vll', '4')
# (77, 'jpc', '7')
# (184, 'blj', '6')
# (68, 'rhj', -1)
# (89, 'gkg', -1)
# (254, 'shc', -1)
# (170, 'kgh', -1)
# (227, 'bqkxm', -1)
# (174, 'qvg', '4')
# (28, 'ht', '7')
# (10, 'xr', '3')
# (63, 'czr', -1)
# (118, 'vpp', -1)
# (77, 'kb', -1)
# (1, 'sdz', '6')
# (31, 'xkxt', '9')
# (164, 'xl', '8')
# (201, 'vc', -1)
# (11, 'xc', -1)
# (13, 'zkh', '6')
# (155, 'gnrt', '4')
# (80, 'hh', -1)
# (201, 'gb', -1)
# (52, 'kfc', -1)
# (85, 'sb', -1)
# (218, 'ft', '7')
# (32, 'qlc', -1)
# (175, 'nq', '3')
# (236, 'mskmt', -1)
# (82, 'vhppt', -1)
# (91, 'pgd', -1)
# (108, 'jvtx', -1)
# (75, 'gzsvq', '9')
# (90, 'btd', -1)
# (53, 'qd', '5')
# (171, 'ch', '1')
# (165, 'vlpc', '4')
# (209, 'ns', '9')
# (6, 'zppl', -1)
# (157, 'xbpsnb', '3')
# (3, 'pc', -1)
# (228, 'lnj', '3')
# (254, 'dz', -1)
# (36, 'pt', '4')
# (101, 'vxjjs', -1)
# (3, 'pc', '1')
# (78, 'nvj', '3')
# (135, 'qkk', -1)
# (158, 'np', -1)
# (51, 'rmtp', '8')
# (247, 'zm', '5')
# (244, 'xvf', '9')
# (114, 'hj', '1')
# (42, 'hglmnt', '7')
# (109, 'rpvcr', -1)
# (184, 'tgm', -1)
# (113, 'szt', -1)
# (57, 'tmx', '3')
# (94, 'xhqbpk', '8')
# (31, 'xkxt', -1)
# (109, 'lq', '7')
# (237, 'sz', -1)
# (252, 'jlf', -1)
# (117, 'tq', -1)
# (131, 'mvp', -1)
# (152, 'vpr', '8')
# (154, 'cg', -1)
# (215, 'mxb', -1)
# (153, 'dtq', '5')
# (140, 'hmbqd', '3')
# (156, 'sqvr', '9')
# (21, 'sqq', '1')
# (158, 'ccdd', '5')
# (75, 'vxm', -1)
# (55, 'hxg', '6')
# (45, 'zmf', '5')
# (241, 'cjvn', -1)
# (46, 'kkh', '4')
# (36, 'vmq', '9')
# (146, 'prvz', '1')
# (184, 'czzq', '6')
# (15, 'xmj', '6')
# (254, 'tfd', '3')
# (175, 'mnd', '4')
# (74, 'mm', '1')
# (188, 'ddt', -1)
# (137, 'cf', '1')
# (72, 'crs', -1)
# (2, 'xtcc', -1)
# (103, 'dsp', '9')
# (117, 'qlh', '3')
# (116, 'vck', '8')
# (188, 'ddt', -1)
# (77, 'jpc', -1)
# (197, 'ngp', -1)
# (102, 'rlgq', -1)
# (189, 'bk', -1)
# (126, 'dvhvf', '3')
# (200, 'vr', -1)
# (11, 'kld', -1)
# (4, 'hpjb', -1)
# (92, 'jrztr', '8')
# (162, 'mkffn', '1')
# (52, 'drtj', '6')
# (133, 'qlx', -1)
# (70, 'xjd', -1)
# (52, 'drtj', '2')
# (240, 'zfp', '9')
# (126, 'dvhvf', -1)
# (238, 'dj', '7')
# (63, 'gx', -1)
# (212, 'zz', '5')
# (101, 'zcrf', -1)
# (254, 'tfd', '9')
# (171, 'ch', -1)
# (241, 'bgh', '4')
# (159, 'rcj', '6')
# (239, 'tcx', '1')
# (145, 'kf', -1)
# (161, 'hzbm', -1)
# (188, 'bz', -1)
# (91, 'fkj', -1)
# (103, 'qv', '5')
# (194, 'zqg', -1)
# (152, 'vpr', -1)
# (126, 'lr', '1')
# (226, 'hxb', '8')
# (47, 'gh', -1)
# (242, 'msbjv', -1)
# (130, 'ljl', '5')
# (231, 'jm', '8')
# (251, 'gxdx', '8')
# (82, 'bdkdjc', -1)
# (102, 'mxnc', '4')
# (252, 'bbph', '5')
# (125, 'mp', -1)
# (188, 'bz', '8')
# (53, 'qd', -1)
# (20, 'pd', -1)
# (48, 'pjss', '7')
# (250, 'hr', '6')
# (94, 'kc', -1)
# (127, 'rpm', -1)
# (18, 'bp', '3')
# (36, 'pt', -1)
# (28, 'xzmm', '9')
# (77, 'jpc', -1)
# (230, 'zl', '2')
# (113, 'szt', '3')
# (90, 'btd', '1')
# (174, 'qvg', '3')
# (32, 'qlc', '5')
# (102, 'rlgq', -1)
# (205, 'bhs', -1)
# (155, 'qjlt', '1')
# (166, 'crmd', '9')
# (35, 'cbgltg', -1)
# (21, 'sqq', '3')
# (189, 'sdv', '3')
# (72, 'mgdzf', -1)
# (146, 'lkk', -1)
# (13, 'gbt', '5')
# (34, 'grcdlv', '6')
# (226, 'nt', -1)
# (103, 'qv', -1)
# (172, 'ckqkrp', -1)
# (27, 'xs', -1)
# (30, 'vh', '1')
# (215, 'djlm', '2')
# (6, 'qpkz', '7')
# (243, 'cxhp', -1)
# (6, 'qpkz', '7')
# (117, 'zsrf', '2')
# (168, 'jzd', -1)
# (110, 'rpl', -1)
# (115, 'nsskd', '4')
# (56, 'ttcmzv', -1)
# (107, 'cbv', -1)
# (178, 'tfvb', -1)
# (162, 'vjvl', '1')
# (231, 'lkp', '5')
# (123, 'gjz', -1)
# (178, 'tfvb', '5')
# (144, 'vxb', -1)
# (188, 'bz', -1)
# (2, 'mqfxv', -1)
# (243, 'lpg', '4')
# (152, 'xlt', -1)
# (66, 'dfx', -1)
# (236, 'tx', -1)
# (177, 'ptncqk', '2')
# (144, 'vxb', -1)
# (142, 'mq', '8')
# (29, 'vqtr', '7')
# (85, 'rs', -1)
# (31, 'xkxt', '7')
# (60, 'xrr', -1)
# (190, 'pn', -1)
# (129, 'dmfz', '1')
# (130, 'xj', -1)
# (164, 'xl', '5')
# (184, 'czzq', -1)
# (107, 'cbv', -1)
# (42, 'zp', '3')
# (243, 'lpg', -1)
# (156, 'sqvr', -1)
# (46, 'vx', '5')
# (28, 'mhg', '6')
# (236, 'mskmt', '4')
# (152, 'vfnjd', '7')
# (144, 'zv', -1)
# (63, 'czr', '8')
# (87, 'dzbkl', '4')
# (76, 'zr', -1)
# (230, 'cqrp', -1)
# (231, 'jm', -1)
# (194, 'zqg', -1)
# (221, 'sj', -1)
# (251, 'gxdx', -1)
# (218, 'ft', '2')
# (187, 'sh', -1)
# (112, 'jf', -1)
# (5, 'kpz', '9')
# (85, 'sb', '2')
# (122, 'ztl', -1)
# (114, 'hj', -1)
# (205, 'dbznbm', '3')
# (147, 'gth', -1)
# (16, 'sm', '8')
# (62, 'zmg', '7')
# (252, 'jlf', '8')
# (115, 'gl', '6')
# (108, 'jvtx', '7')
# (205, 'tcv', '1')
# (154, 'cfq', '7')
# (136, 'rv', -1)
# (109, 'lq', '6')
# (85, 'kvd', '5')
# (64, 'vj', -1)
# (234, 'czm', '8')
# (141, 'pgv', -1)
# (129, 'lzk', '7')
# (98, 'gk', -1)
# (104, 'vgcx', '9')
# (142, 'mq', -1)
# (28, 'ljf', '3')
# (203, 'sx', -1)
# (68, 'rhj', '3')
# (244, 'nf', -1)
# (193, 'tcgcp', -1)
# (175, 'jdq', '3')
# (28, 'xzmm', '7')
# (129, 'gtv', -1)
# (126, 'dvhvf', '2')
# (189, 'bk', '1')
# (142, 'zdrpn', -1)
# (140, 'hmbqd', -1)
# (28, 'xzmm', '1')
# (103, 'trq', -1)
# (87, 'dzbkl', '1')
# (231, 'jm', '3')
# (155, 'qjlt', '4')
# (11, 'hs', -1)
# (26, 'tkk', -1)
# (26, 'tkk', -1)
# (200, 'vr', -1)
# (236, 'bvfn', -1)
# (222, 'ck', '2')
# (243, 'lpg', -1)
# (86, 'rd', -1)
# (243, 'flq', -1)
# (86, 'knjsp', '8')
# (172, 'xvksp', '1')
# (155, 'gnrt', -1)
# (77, 'zc', '5')
# (243, 'cxhp', -1)
# (184, 'czzq', -1)
# (20, 'bjhvj', '2')
# (64, 'vj', '8')
# (70, 'pv', -1)
# (53, 'qd', -1)
# (155, 'gnrt', -1)
# (86, 'rd', -1)
# (84, 'sq', -1)
# (66, 'dfx', '3')
# (176, 'ms', -1)
# (113, 'tdvs', -1)
# (222, 'ck', '2')
# (172, 'bj', -1)
# (194, 'bssj', '4')
# (24, 'gsdj', '7')
# (54, 'pf', -1)
# (7, 'tsld', '4')
# (116, 'vck', -1)
# (177, 'ptncqk', '4')
# (127, 'rpm', '2')
# (205, 'ldm', -1)
# (47, 'gh', '6')
# (57, 'ml', '6')
# (230, 'cqrp', '9')
# (97, 'gz', -1)
# (144, 'jbd', -1)
# (5, 'kpz', -1)
# (67, 'fvgqlc', -1)
# (125, 'mp', -1)
# (201, 'gb', -1)
# (30, 'fx', '2')
# (194, 'bssj', -1)
# (30, 'fx', -1)
# (117, 'zsrf', '6')
# (90, 'btd', -1)
# (188, 'fpf', '6')
# (254, 'shc', '5')
# (77, 'kb', '8')
# (48, 'rjt', -1)
# (249, 'zmr', '4')
# (175, 'nq', -1)
# (194, 'njj', -1)
# (102, 'rlgq', -1)
# (220, 'th', '7')
# (142, 'rqhc', -1)
# (237, 'sz', -1)
# (197, 'jk', '6')
# (194, 'xqsv', -1)
# (238, 'dj', '7')
# (226, 'nt', -1)
# (254, 'dz', -1)
# (6, 'grgf', '6')
# (146, 'xz', -1)
# (98, 'gk', '9')
# (240, 'rvh', '7')
# (51, 'pkx', '8')
# (203, 'xchx', '4')
# (46, 'hf', '5')
# (122, 'fnf', -1)
# (133, 'fdk', -1)
# (104, 'px', -1)
# (115, 'gl', '6')
# (166, 'vp', -1)
# (140, 'hmbqd', '1')
# (174, 'bff', '4')
# (112, 'xx', -1)
# (201, 'ppljc', '7')
# (231, 'jm', -1)
# (228, 'lnj', -1)
# (147, 'xk', -1)
# (48, 'pjss', -1)
# (75, 'vxm', -1)
# (218, 'ft', -1)
# (123, 'qgc', '9')
# (14, 'rlfxr', -1)
# (57, 'ml', '4')
# (54, 'xxf', '2')
# (56, 'nj', -1)
# (55, 'hxg', -1)
# (36, 'vmq', '7')
# (133, 'fdk', '2')
# (118, 'vpp', -1)
# (174, 'qvg', '1')
# (37, 'brqld', -1)
# (131, 'cld', '8')
# (182, 'qfkt', -1)
# (98, 'gk', -1)
# (130, 'hz', -1)
# (202, 'tldf', '1')
# (147, 'gth', '9')
# (252, 'bbph', -1)
# (145, 'gvd', '3')
# (85, 'sb', -1)
# (157, 'xbpsnb', -1)
# (8, 'km', '1')
# (11, 'xc', '4')
# (24, 'll', -1)
# (142, 'mq', '1')
# (144, 'vxb', -1)
# (215, 'djlm', -1)
# (251, 'gxdx', -1)
# (121, 'bg', -1)
# (178, 'zx', -1)
# (194, 'zqg', -1)
# (246, 'qrs', -1)
# (75, 'gzsvq', '8')
# (142, 'rqhc', -1)
# (240, 'zfp', -1)
# (145, 'brscg', -1)
# (11, 'xc', '4')
# (129, 'lzk', '2')
# (77, 'zc', -1)
# (249, 'zmr', '3')
# (190, 'pn', -1)
# (238, 'bxt', '9')
# (46, 'hf', -1)
# (236, 'tx', -1)
# (186, 'dfp', '9')
# (133, 'mtt', '4')
# (116, 'vck', '1')
# (222, 'tdf', '6')
# (114, 'fff', '2')
# (200, 'vr', -1)
# (91, 'pgd', -1)
# (51, 'pkx', '1')
# (168, 'fb', '7')
# (34, 'rp', -1)
# (92, 'jrztr', '5')
# (178, 'tfvb', '5')
# (37, 'qgm', '3')
# (212, 'zz', -1)
# (57, 'tmx', '8')
# (190, 'bvf', '3')
# (162, 'mkffn', '5')
# (43, 'lkt', '4')
# (197, 'jk', -1)
# (15, 'tk', -1)
# (64, 'phxp', '4')
# (152, 'vfnjd', -1)
# (193, 'nvxng', -1)
# (84, 'sq', '4')
# (134, 'rzqgr', -1)
# (133, 'vcl', '3')
# (146, 'sblkv', '4')
# (243, 'cxhp', '4')
# (236, 'bvfn', '3')
# (12, 'zmbc', -1)
# (96, 'cmthnv', -1)
# (138, 'dtpb', '4')
# (164, 'xl', -1)
# (91, 'pgd', -1)
# (56, 'ttcmzv', -1)
# (101, 'sr', -1)
# (18, 'bp', -1)
# (205, 'tcv', '7')
# (166, 'crmd', '4')
# (242, 'kzbmn', '8')
# (101, 'dq', '6')
# (252, 'vf', '8')
# (245, 'kpj', '9')
# (57, 'ml', '3')
# (146, 'xz', -1)
# (153, 'cv', '3')
# (64, 'vj', '6')
# (34, 'dscx', -1)
# (237, 'ktlshg', '7')
# (249, 'nklsq', '5')
# (107, 'cbv', '2')
# (45, 'zmf', '8')
# (47, 'mfl', -1)
# (242, 'msbjv', -1)
# (25, 'qrf', '6')
# (237, 'sz', -1)
# (165, 'vlpc', -1)
# (133, 'vcl', -1)
# (178, 'tfvb', '1')
# (17, 'cn', -1)
# (8, 'km', -1)
# (58, 'jkzk', '3')
# (65, 'fnkb', -1)
# (30, 'vh', '4')
# (197, 'jk', -1)
# (157, 'xbpsnb', '2')
# (201, 'ppljc', '4')
# (114, 'gsh', -1)
# (190, 'pn', '9')
# (174, 'bff', -1)
# (86, 'rd', '5')
# (242, 'kzbmn', -1)
# (17, 'cn', -1)
# (250, 'hr', -1)
# (75, 'gzsvq', -1)
# (102, 'mxnc', '9')
# (213, 'zkhx', '6')
# (51, 'rmtp', -1)
# (57, 'tng', -1)
# (226, 'hxb', '9')
# (28, 'ljf', '4')
# (103, 'trq', '5')
# (171, 'dds', '4')
# (214, 'hsk', '7')
# (145, 'kf', '3')
# (21, 'sqq', '1')
# (132, 'gm', -1)
# (94, 'kc', -1)
# (212, 'zz', '3')
# (4, 'nv', -1)
# (11, 'hs', -1)
# (3, 'pc', -1)
# (161, 'jvdm', '1')
# (252, 'vf', -1)
# (121, 'sksgsn', -1)
# (101, 'sr', -1)
# (152, 'xlt', -1)
# (168, 'jzd', '4')
# (115, 'gl', -1)
# (139, 'ctxhnf', '2')
# (41, 'lm', '5')
# (153, 'vpc', -1)
# (90, 'btd', '5')
# (133, 'vcl', '4')
# (122, 'vlx', '4')
# (187, 'sh', '7')
# (13, 'zkh', '5')
# (158, 'ldfh', '1')
# (101, 'dq', '6')
# (146, 'sblkv', -1)
# (205, 'bhs', '6')
# (63, 'gx', '4')
# (142, 'rqhc', -1)
# (116, 'vck', -1)
# (43, 'mvrzl', -1)
# (210, 'nd', -1)
# (214, 'prt', '8')
# (241, 'cjvn', '4')
# (45, 'pql', -1)
# (112, 'jf', '6')
# (230, 'kk', '8')
# (109, 'rpvcr', -1)
# (7, 'tsld', -1)
# (230, 'cqrp', -1)
# (94, 'jt', -1)
# (131, 'cld', '4')
# (63, 'rlkv', -1)
# (188, 'bz', '2')
# (166, 'phjd', '4')
# (210, 'kmtv', '7')
# (150, 'rpqs', '8')
# (11, 'xc', '8')
# (134, 'tr', -1)
# (234, 'hb', -1)
# (62, 'zmg', '9')
# (178, 'mkj', -1)
# (193, 'tcgcp', '1')
# (192, 'frzn', '5')
# (202, 'tldf', -1)
# (174, 'lrhtt', -1)
# (177, 'ptncqk', '6')
# (48, 'pjss', -1)
# (145, 'gvd', '6')
# (176, 'njx', '8')
# (86, 'knjsp', -1)
# (141, 'pgv', -1)
# (99, 'ndvk', -1)
# (149, 'ftk', -1)
# (23, 'tdlc', -1)
# (161, 'kv', -1)
# (227, 'jcv', -1)
# (92, 'pff', '2')
# (75, 'gzsvq', -1)
# (114, 'hj', -1)
# (150, 'rpqs', '1')
# (11, 'hs', -1)
# (228, 'lnj', '4')
# (28, 'pqk', -1)
# (43, 'mvrzl', -1)
# (228, 'lnj', '6')
# (242, 'msbjv', '2')
# (250, 'xb', '5')
# (188, 'pkq', -1)
# (4, 'hpjb', '7')
# (86, 'rd', '4')
# (174, 'vll', '9')
# (62, 'hbt', '5')
# (230, 'rdhshm', -1)
# (0, 'pld', '3')
# (207, 'ggvptg', -1)
# (14, 'jjz', -1)
# (43, 'lkt', -1)
# (168, 'xms', -1)
# (161, 'jvdm', -1)
# (86, 'rd', -1)
# (134, 'tr', '6')
# (63, 'cbnfv', -1)
# (249, 'vfm', -1)
# (63, 'gx', '4')
# (147, 'pbq', -1)
# (250, 'hr', -1)
# (94, 'zd', '9')
# (152, 'vpr', -1)
# (81, 'gj', '9')
# (11, 'hs', '9')
# (97, 'svdt', '2')
# (43, 'lkt', '7')
# (158, 'gjm', '5')
# (194, 'zqg', -1)
# (188, 'fpf', '6')
# (0, 'rn', -1)
# (219, 'fsb', -1)
# (109, 'rpvcr', -1)
# (63, 'rlkv', -1)
# (11, 'xc', -1)
# (131, 'mvp', '3')
# (112, 'jf', '3')
# (137, 'kqbk', -1)
# (217, 'grp', '1')
# (200, 'vr', -1)
# (188, 'ddt', '7')
# (198, 'zzhj', '1')
# (146, 'rnr', -1)
# (28, 'ljf', -1)
# (152, 'vpr', -1)
# (192, 'frzn', -1)
# (58, 'jkzk', '7')
# (54, 'xxf', -1)
# (242, 'kzbmn', -1)
# (249, 'zmr', '4')
# (177, 'bcl', '7')
# (162, 'vjvl', '9')
# (130, 'xj', -1)
# (231, 'jm', -1)
# (23, 'gxh', '2')
# (176, 'kqd', '1')
# (141, 'pgv', '8')
# (154, 'cfq', '7')
# (152, 'td', -1)
# (241, 'bgh', '3')
# (144, 'zv', '9')
# (86, 'lthn', -1)
# (202, 'fd', '7')
# (48, 'rjt', '6')
# (137, 'qx', '3')
# (166, 'phjd', -1)
# (102, 'mxnc', -1)
# (54, 'pf', '1')
# (234, 'hpr', '9')
# (113, 'tdvs', -1)
# (197, 'ngp', -1)
# (118, 'vpp', '8')
# (57, 'tng', '6')
# (117, 'zsrf', '7')
# (66, 'dfx', '3')
# (197, 'pcr', -1)
# (77, 'kb', -1)
# (77, 'kb', -1)
# (117, 'qlh', '6')
# (216, 'ldsphm', -1)
# (14, 'jjz', '7')
# (190, 'pn', '2')
# (172, 'lrn', -1)
# (130, 'rjbd', -1)
# (163, 'tkd', '7')
# (246, 'qrs', '1')
# (29, 'vqtr', -1)
# (221, 'sj', '2')
# (0, 'rn', '6')
# (133, 'vcl', '4')
# (82, 'bdkdjc', '1')
# (6, 'grgf', -1)
# (81, 'vk', -1)
# (174, 'lrhtt', -1)
# (247, 'zm', '8')
# (132, 'vn', -1)
# (25, 'qrf', '6')
# (164, 'xl', '6')
# (244, 'nf', -1)
# (162, 'mkffn', -1)
# (134, 'tr', '2')
# (206, 'qm', '8')
# (215, 'djlm', '3')
# (215, 'mxb', -1)
# (131, 'mvp', -1)
# (108, 'kblc', '8')
# (190, 'pn', '1')
# (28, 'xd', '3')
# (76, 'zr', -1)
# (103, 'kdll', -1)
# (82, 'lhdz', '3')
# (86, 'knjsp', '2')
# (129, 'lzk', -1)
# (63, 'cbnfv', -1)
# (142, 'mq', -1)
# (210, 'nd', '1')
# (141, 'pgv', '7')
# (28, 'xd', '3')
# (101, 'vxjjs', -1)
# (226, 'hxb', '7')
# (221, 'sj', -1)
# (227, 'fkr', '1')
# (174, 'zsq', -1)
# (66, 'dfx', -1)
# (255, 'tsx', '8')
# (156, 'xctm', '1')
# (121, 'sksgsn', -1)
# (96, 'cmthnv', -1)
# (77, 'jpc', '8')
# (207, 'ggvptg', -1)
# (23, 'gxh', '7')
# (12, 'zmbc', -1)
# (84, 'sq', -1)
# (92, 'rpz', -1)
# (108, 'kblc', -1)
# (171, 'fjjtm', -1)
# (176, 'kqd', '4')
# (194, 'bssj', -1)
# (3, 'qdhf', '8')
# (201, 'ppljc', -1)
# (20, 'pd', '6')
# (74, 'mm', -1)
# (72, 'mgdzf', -1)
# (226, 'hxb', '8')
# (37, 'grgrps', '4')
# (244, 'xvf', '9')
# (231, 'lkp', '1')
# (193, 'tcgcp', -1)
# (228, 'lnj', '8')
# (222, 'ck', '7')
# (193, 'nkh', -1)
# (121, 'bkht', '2')
# (92, 'kzmhkg', '2')
# (24, 'gsdj', '1')
# (48, 'pjss', -1)
# (57, 'tng', '1')
# (12, 'hd', -1)
# (164, 'xl', '4')
# (231, 'lkp', -1)
# (242, 'vlp', -1)
# (184, 'fr', '9')
# (116, 'vck', -1)
# (65, 'xnk', '5')
# (84, 'sq', -1)
# (247, 'zm', '4')
# (203, 'fqt', -1)
# (242, 'kzbmn', '3')
# (171, 'fjjtm', -1)
# (175, 'jdq', -1)
# (236, 'tx', '8')
# (109, 'rpvcr', '7')
# (145, 'gvd', '2')
# (87, 'dzbkl', -1)
# (57, 'tmx', -1)
# (74, 'gpkh', '8')
# (32, 'qlc', -1)
# (192, 'pkkj', '2')
# (14, 'jjz', '5')
# (28, 'xzmm', '8')
# (146, 'lkk', '9')
# (142, 'mq', -1)
# (85, 'kvd', -1)
# (64, 'fz', '7')
# (193, 'nvxng', '1')
# (6, 'lz', '3')
# (28, 'pqk', -1)
# (161, 'kv', -1)
# (255, 'tsx', '4')
# (80, 'lxl', '6')
# (252, 'zbtzr', '5')
# (218, 'ft', -1)
# (236, 'tx', '2')
# (44, 'xgfjsz', '9')
# (252, 'bbph', -1)
# (201, 'vc', '6')
# (28, 'ljf', -1)
# (78, 'nvj', -1)
# (55, 'ccq', -1)
# (85, 'sb', -1)
# (147, 'xk', '1')
# (48, 'pjss', -1)
# (117, 'zsrf', '5')
# (210, 'kmtv', '9')
# (205, 'tcv', -1)
# (101, 'dq', -1)
# (242, 'kzbmn', -1)
# (198, 'zzhj', '9')
# (146, 'xz', '2')
# (210, 'kmtv', '5')
# (129, 'lzk', '3')
# (146, 'prvz', -1)
# (205, 'tcv', -1)
# (158, 'cbfc', -1)
# (172, 'lrn', '9')
# (64, 'vj', -1)
# (127, 'rpm', -1)
# (245, 'kpj', '4')
# (173, 'nmr', -1)
# (33, 'sn', '2')
# (24, 'll', '4')
# (146, 'sblkv', '9')
# (27, 'xs', '8')
# (24, 'll', '4')
# (144, 'ld', '3')
# (142, 'rqhc', '5')
# (108, 'jvtx', '1')
# (6, 'lbsmh', '8')
# (102, 'rlgq', '1')
# (36, 'pt', -1)
# (164, 'xl', -1)
# (114, 'hj', -1)
# (62, 'hv', -1)
# (243, 'cxhp', '8')
# (224, 'pp', -1)
# (63, 'gx', '8')
# (82, 'bdkdjc', -1)
# (210, 'kmtv', -1)
# (97, 'svdt', '6')
# (154, 'cfq', '4')
# (215, 'djlm', '4')
# (33, 'sn', -1)
# (63, 'gx', '8')
# (15, 'xmj', '5')
# (7, 'tsld', '8')
# (68, 'rhj', '3')
# (10, 'xr', -1)
# (241, 'cjvn', '2')
# (230, 'rdhshm', '6')
# (173, 'bkhdt', -1)
# (65, 'fnkb', -1)
# (46, 'pcjxqx', -1)
# (241, 'bgh', -1)
# (244, 'nf', '8')
# (81, 'vk', '9')
# (178, 'tfvb', '6')
# (188, 'ddt', -1)
# (130, 'ljl', -1)
# (197, 'jk', '8')
# (241, 'cjvn', -1)
# (87, 'fndsl', '5')
# (82, 'vhppt', '6')
# (241, 'bgh', '1')
# (174, 'bff', '2')
# (190, 'lbld', '2')
# (108, 'jvtx', -1)
# (87, 'fndsl', '6')
# (180, 'jxnd', -1)
# (28, 'xzmm', '8')
# (113, 'tdvs', '9')
# (145, 'gvd', -1)
# (213, 'zkhx', '7')
# (97, 'gsg', -1)
# (114, 'fff', -1)
# (102, 'rlgq', '9')
# (92, 'jrztr', -1)
# (240, 'zfp', '4')
# (145, 'brscg', -1)
# (174, 'vll', '9')
# (166, 'vp', -1)
# (82, 'bdkdjc', -1)
# (243, 'flq', '8')
# (144, 'jbd', '1')
# (115, 'nsskd', '7')
# (161, 'jvdm', '2')
# (12, 'hd', '5')
# (52, 'kfc', '1')
# (26, 'tkk', -1)
# (193, 'nvxng', -1)
# (54, 'pf', '8')
# (147, 'gth', -1)
# (32, 'qlc', -1)
# (42, 'zp', '6')
# (103, 'trq', '9')
# (3, 'pc', '3')
# (147, 'xk', -1)
# (178, 'mkj', '9')
# (154, 'cfq', -1)
# (165, 'hql', '4')
# (11, 'kld', -1)
# (15, 'xmj', -1)
# (252, 'bbph', -1)
# (172, 'lrn', '8')
# (234, 'hb', '1')
# (139, 'ctxhnf', '7')
# (184, 'czzq', '6')
# (90, 'btd', -1)
# (36, 'pt', '1')
# (64, 'fz', -1)
# (108, 'kblc', '7')
# (92, 'jrztr', '2')
# (213, 'zkhx', '3')
# (204, 'dh', -1)
# (166, 'crmd', -1)
# (104, 'vgcx', '5')
# (130, 'ljl', '8')
# (11, 'kld', -1)
# (63, 'rlkv', -1)
# (237, 'sz', -1)
# (238, 'bxt', -1)
# (98, 'jdqmf', -1)
# (247, 'zm', '1')
# (184, 'blj', -1)
# (177, 'ptncqk', -1)
# (242, 'qsxf', -1)
# (149, 'ftk', -1)
# (108, 'kblc', '5')
# (158, 'np', '6')
# (63, 'cbnfv', '1')
# (97, 'gsg', -1)
# (250, 'hr', '3')
# (8, 'ggj', '2')
# (162, 'kg', -1)
# (246, 'gdglbv', -1)
# (37, 'qgm', '5')
# (11, 'xc', -1)
# (29, 'gv', -1)
# (37, 'grgrps', -1)
# (228, 'lnj', -1)
# (215, 'mxb', -1)
# (3, 'qdhf', '1')
# (170, 'kgh', '6')
# (127, 'rpm', -1)
# (152, 'dt', '6')
# (171, 'dds', -1)
# (254, 'tfd', -1)
# (158, 'cbfc', -1)
# (202, 'fd', '4')
# (138, 'dtpb', '2')
# (67, 'fvgqlc', '1')
# (94, 'kc', -1)
# (60, 'xrr', -1)
# (203, 'sx', '7')
# (189, 'sdv', -1)
# (43, 'lkt', -1)
# (54, 'pf', '5')
# (20, 'pd', '1')
# (45, 'pql', '7')
# (158, 'ldfh', -1)
# (240, 'zfp', '1')
# (133, 'qlx', -1)
# (147, 'xk', '5')
# (118, 'vpp', '4')
# (23, 'gxh', '7')
# (179, 'kh', '4')
# (214, 'prt', -1)
# (5, 'kpz', -1)
# (57, 'ml', -1)
# (131, 'cld', '7')
# (139, 'ctd', '4')
# (1, 'sdz', '9')
# (204, 'dh', -1)
# (130, 'xj', '2')
# (51, 'pkx', -1)
# (102, 'znkc', -1)
# (12, 'hd', '2')
# (48, 'jlrh', '2')
# (217, 'grp', -1)
# (197, 'jk', '7')
# (175, 'nq', -1)
# (117, 'qlh', -1)
# (21, 'nlk', -1)
# (97, 'gsg', '6')
# (0, 'rn', '5')
# (85, 'rs', '3')
# (108, 'kblc', -1)
# (62, 'hv', -1)
# (215, 'nvc', -1)
# (144, 'zv', '5')
# (6, 'lbsmh', -1)
# (28, 'ljf', -1)
# (149, 'ftk', '4')
# (225, 'ttgpr', '4')
# (31, 'bkr', '5')
# (194, 'xqsv', -1)
# (188, 'pkq', -1)
# (108, 'jvtx', -1)
# (66, 'dfx', '2')
# (13, 'gbt', '1')
# (8, 'km', '1')
# (226, 'hxb', -1)
# (152, 'td', '4')
# (113, 'szt', -1)
# (239, 'tcx', '1')
# (255, 'tsx', '9')
# (166, 'vp', '5')
# (146, 'prvz', -1)
# (127, 'rpm', -1)
# (33, 'qjv', -1)
# (180, 'pcgj', '3')
# (98, 'jdqmf', -1)
# (154, 'cfq', '6')
# (147, 'ktbr', '4')
# (152, 'vpr', -1)
# (94, 'zd', -1)
# (230, 'rdhshm', -1)
# (20, 'pd', '5')
# (103, 'kdll', '8')
# (84, 'sq', '4')
# (98, 'gk', -1)
# (249, 'zmr', '7')
# (172, 'xvksp', -1)
# (227, 'bqkxm', -1)
# (241, 'cjvn', '4')
# (251, 'gxdx', -1)
# (0, 'pld', '9')
# (46, 'vx', -1)
# (99, 'lvq', -1)
# (109, 'rpvcr', -1)
# (231, 'jm', -1)
# (184, 'czzq', -1)
# (78, 'nvj', -1)
# (159, 'rcj', -1)
# (239, 'tcx', '9')
# (108, 'kblc', '2')
# (137, 'kqbk', '7')
# (172, 'xvksp', '7')
# (149, 'ftk', '8')
# (173, 'nmr', -1)
# (155, 'gnrt', '7')
# (6, 'qpkz', -1)
# (131, 'mvp', -1)
# (152, 'vpr', '3')
# (46, 'kkh', '1')
# (63, 'cbnfv', -1)
# (240, 'rvh', -1)
# (84, 'dp', '8')
# (252, 'jlf', -1)
# (131, 'mvp', -1)
# (239, 'tcx', -1)
# (194, 'xqsv', '9')
# (254, 'shc', -1)
# (0, 'rn', -1)
# (175, 'mnd', '9')
# (45, 'pql', -1)
# (133, 'fdk', '1')
# (85, 'kvd', '7')
# (190, 'bvf', '8')
# (226, 'hxb', -1)
# (215, 'nvc', '8')
# (101, 'zcrf', '7')
# (234, 'czm', -1)
# (129, 'dmfz', '6')
# (102, 'rlgq', -1)
# (213, 'vgx', -1)
# (82, 'lhdz', -1)
# (80, 'lxl', -1)
# (205, 'ldm', '1')
# (28, 'mhg', '3')
# (157, 'xbpsnb', '7')
# (188, 'fpf', -1)
# (116, 'vck', -1)
# (191, 'nmd', -1)
# (77, 'zc', '3')
# (226, 'nt', '4')
# (129, 'dmfz', '9')
# (7, 'tsld', -1)
# (107, 'cbv', '4')
# (101, 'dq', -1)
# (215, 'mxb', '1')
# (175, 'nq', '8')
# (51, 'pkx', -1)
# (129, 'dmfz', -1)
# (168, 'xms', '3')
# (28, 'cpqx', -1)
# (63, 'gx', -1)
# (176, 'njx', -1)
# (102, 'rlgq', -1)
# (28, 'mhg', '3')
# (75, 'vxm', -1)
# (182, 'qfkt', -1)
# (12, 'hd', -1)
# (78, 'nvj', -1)
# (194, 'zqg', -1)
# (44, 'xgfjsz', -1)
# (101, 'zcrf', -1)
# (63, 'gx', '3')
# (114, 'gsh', -1)
# (152, 'vpr', '2')
# (234, 'hpr', '6')
# (10, 'xbp', -1)
# (120, 'rf', '1')
# (188, 'ddt', '4')
# (103, 'trq', '3')
# (236, 'mskmt', -1)
# (242, 'vlp', -1)
# (77, 'kb', '2')
# (117, 'zsrf', '4')
# (189, 'bk', -1)
# (32, 'qlc', '3')
# (108, 'jvtx', '3')
# (3, 'pc', '5')
# (121, 'sksgsn', -1)
# (213, 'zkhx', '7')
# (145, 'gvd', '8')
# (85, 'rs', -1)
# (186, 'dfp', -1)
# (47, 'gh', -1)
# (6, 'grgf', '3')
# (206, 'qm', '3')
# (158, 'gjm', '9')
# (162, 'vjvl', '3')
# (238, 'ltn', -1)
# (48, 'pjss', -1)
# (81, 'vk', -1)
# (152, 'vpr', '5')
# (37, 'qblf', -1)
# (133, 'fdk', -1)
# (146, 'sblkv', '6')
# (195, 'pflmt', -1)
# (132, 'gm', -1)
# (189, 'sdv', -1)
# (24, 'gsdj', '8')
# (243, 'lpg', '1')
# (249, 'zmr', -1)
# (92, 'kzmhkg', -1)
# (156, 'xctm', -1)
# (142, 'rqhc', -1)
# (247, 'zm', -1)
# (101, 'rkjn', -1)
# (23, 'gxh', '7')
# (129, 'gtv', -1)
# (29, 'vqtr', '4')
# (142, 'mq', '2')
# (0, 'pld', -1)
# (92, 'rpz', -1)
# (68, 'rhj', '4')
# (102, 'rlgq', -1)
# (54, 'pf', '6')
# (94, 'jt', '5')
# (46, 'vx', -1)
# (252, 'bbph', '3')
# (227, 'fkr', -1)
# (51, 'rmtp', '8')
# (52, 'drtj', -1)
# (174, 'vll', -1)
# (76, 'zr', -1)
# (136, 'rv', -1)
# (112, 'jf', -1)
# (217, 'gr', -1)
# (166, 'crmd', '5')
# (118, 'tb', -1)
# (93, 'zs', -1)
# (177, 'ptncqk', '5')
# (142, 'mq', '9')
# (220, 'th', -1)
# (165, 'vlpc', '4')
# (180, 'xbz', '5')
# (49, 'tm', -1)
# (187, 'sh', '3')
# (31, 'bkr', '3')
# (56, 'ttcmzv', -1)
# (12, 'hd', '7')
# (50, 'dn', '8')
# (176, 'kqd', -1)
# (63, 'ntm', -1)
# (51, 'pkx', -1)
# (137, 'kqbk', '8')
# (122, 'fnf', -1)
# (60, 'fhn', -1)
# (193, 'nkh', '1')
# (154, 'cg', -1)
# (34, 'rp', -1)
# (57, 'tng', '2')
# (155, 'qjlt', '5')
# (97, 'gsg', '4')
# (84, 'dp', -1)
# (44, 'jb', '2')
# (147, 'lckfs', -1)
# (255, 'tsx', '6')
# (15, 'xmj', '1')
# (237, 'ktlshg', '4')
# (194, 'zqg', '1')
# (28, 'ht', -1)
# (180, 'pcgj', '7')
# (4, 'nv', -1)
# (194, 'hfzz', '4')
# (204, 'dh', -1)
# (238, 'dj', -1)
# (99, 'lvq', '1')
# (153, 'dtq', -1)
# (85, 'rs', '8')
# (210, 'nd', '1')
# (103, 'kdll', -1)
# (117, 'zsrf', '9')
# (188, 'ddt', -1)
# (3, 'pc', '1')
# (130, 'ljl', -1)
# (175, 'jdq', -1)
# (147, 'lckfs', '8')
# (82, 'vhppt', '1')
# (94, 'kc', -1)
# (92, 'rpz', -1)
# (101, 'zcrf', -1)
# (254, 'msn', '7')
# (84, 'sq', '7')
# (118, 'vpp', '4')
# (47, 'gh', '9')
# (209, 'ns', -1)
# (117, 'shj', -1)
# (158, 'np', -1)
# (145, 'gvd', -1)
# (86, 'lthn', -1)
# (230, 'zl', -1)
# (172, 'lrn', '3')
# (51, 'pkx', '9')
# (130, 'rjbd', '4')
# (237, 'ktlshg', -1)
# (152, 'xlt', '2')
# (90, 'btd', -1)
# (184, 'czzq', '9')
# (72, 'mgdzf', -1)
# (75, 'vxm', '3')
# (201, 'fsp', -1)
# (53, 'qd', -1)
# (190, 'pn', -1)
# (254, 'tfd', '2')
# (14, 'fh', -1)
# (158, 'cbfc', '3')
# (184, 'blj', -1)
# (201, 'gb', -1)
# (48, 'jlrh', -1)
# (130, 'hz', '3')
# (165, 'hql', -1)
# (173, 'nmr', -1)
# (190, 'pn', -1)
# (190, 'bvf', -1)
# (239, 'tcx', '7')
# (92, 'kzmhkg', '8')
# (215, 'mxb', -1)
# (212, 'zz', '4')
# (147, 'ktbr', -1)
# (170, 'kgh', '3')
# (215, 'djlm', '4')
# (85, 'rs', -1)
# (87, 'dzbkl', '2')
# (244, 'nf', -1)
# (244, 'xvf', -1)
# (195, 'pflmt', '4')
# (152, 'xlt', '4')
# (13, 'zkh', '8')
# (218, 'ft', '9')
# (140, 'hmbqd', '3')
# (45, 'zmf', '3')
# (197, 'jk', '2')
# (41, 'lm', '7')
# (48, 'pjss', -1)
# (137, 'str', -1)
# (41, 'lm', '9')
# (64, 'fz', -1)
# (234, 'czm', -1)
# (23, 'mj', -1)
# (121, 'sksgsn', '1')
# (234, 'czm', -1)
# (173, 'lshv', -1)
# (29, 'vqtr', -1)
# (247, 'zm', -1)
# (158, 'ccdd', -1)
# (132, 'gm', '6')
# (108, 'kblc', -1)
# (134, 'tr', '9')
# (163, 'tkd', -1)
# (165, 'pqd', -1)
# (12, 'hd', '1')
# (84, 'dp', '8')
# (94, 'xhqbpk', '9')
# (66, 'dfx', '5')
# (103, 'kdll', -1)
# (113, 'szt', -1)
# (92, 'pff', -1)
# (165, 'pqd', -1)
# (158, 'np', -1)
# (254, 'dz', '6')
# (200, 'kkb', '5')
# (97, 'gsg', -1)
# (133, 'fdk', '3')
# (102, 'cgl', -1)
# (107, 'cbv', '7')
# (23, 'mj', -1)
# (44, 'xgfjsz', '2')
# (11, 'hs', -1)
# (25, 'qrf', '3')
# (193, 'nvxng', '2')
# (188, 'bz', -1)
# (85, 'sb', '4')
# (239, 'tcx', '6')
# (97, 'gsg', -1)
# (172, 'bj', -1)
# (93, 'zs', -1)
# (202, 'fd', '3')
# (133, 'fdk', '8')
# (55, 'ccq', '7')
# (102, 'znkc', '2')
# (205, 'bhs', '5')
# (197, 'jk', '5')
# (133, 'fdk', -1)
# (115, 'nsskd', '7')
# (98, 'gk', -1)
# (20, 'pd', '3')
# (168, 'jzd', -1)
# (8, 'szvrqb', '1')
# (25, 'qrf', '5')
# (103, 'kdll', '3')
# (227, 'bqkxm', -1)
# (13, 'zkh', -1)
# (190, 'pn', -1)
# (74, 'gpkh', -1)
# (74, 'tbdzv', '5')
# (166, 'vp', -1)
# (72, 'mgdzf', -1)
# (75, 'vxm', -1)
# (135, 'qkk', -1)
# (72, 'mgdzf', '8')
# (142, 'rqhc', -1)
# (241, 'bgh', '6')
# (75, 'vxm', -1)
# (217, 'gr', '3')
# (175, 'mnd', '1')
# (101, 'rkjn', -1)
# (224, 'pp', -1)
# (163, 'tkd', '8')
# (125, 'mp', -1)
# (15, 'xmj', '2')
# (139, 'ctxhnf', -1)
# (249, 'vfm', '8')
# (197, 'mxp', -1)
# (168, 'jzd', -1)
# (203, 'fqt', '2')
# (60, 'xrr', -1)
# (89, 'gkg', -1)
# (215, 'mxb', -1)
# (173, 'nmr', -1)
# (214, 'hsk', -1)
# (108, 'jvtx', '4')
# (34, 'rp', '5')
# (138, 'dtpb', '8')
# (213, 'zkhx', -1)
# (241, 'cjvn', '1')
# (252, 'vf', -1)
# (94, 'xhqbpk', -1)
# (230, 'zl', '4')
# (230, 'rdhshm', -1)
# (214, 'hsk', -1)
# (42, 'hglmnt', '6')
# (104, 'vgcx', '7')
# (85, 'rs', '4')
# (193, 'tcgcp', -1)
# (98, 'gk', -1)
# (0, 'rn', '6')
# (184, 'blj', -1)
# (205, 'lsn', -1)
# (74, 'tbdzv', '1')
# (177, 'bcl', -1)
# (29, 'gv', '2')
# (213, 'vgx', -1)
# (194, 'xqsv', '9')
# (133, 'qlx', '8')
# (234, 'hpr', '2')
# (63, 'ntm', -1)
# (205, 'ldm', -1)
# (131, 'cld', -1)
# (146, 'vvf', -1)
# (249, 'nklsq', -1)
# (125, 'mp', -1)
# (46, 'kkh', -1)
# (126, 'lr', -1)
# (147, 'gth', -1)
# (188, 'bz', -1)
# (195, 'kx', -1)
# (220, 'th', -1)
# (236, 'mskmt', -1)
# (84, 'dp', '5')
# (153, 'sf', -1)
# (152, 'vpr', '1')
# (130, 'hz', '3')
# (197, 'pcr', -1)
# (4, 'hpjb', -1)
# (92, 'kzmhkg', '1')
# (152, 'xlt', -1)
# (10, 'xbp', '9')
# (249, 'nklsq', '7')
# (158, 'np', '3')
# (134, 'tr', -1)
# (184, 'tgm', '2')
# (224, 'pp', '6')
# (121, 'bkht', -1)
# (188, 'bz', -1)
# (237, 'sz', '6')
# (52, 'hzr', -1)
# (43, 'lkt', -1)
# (206, 'pzd', '9')
# (137, 'kqbk', '8')
# (187, 'sh', -1)
# (13, 'zkh', -1)
# (104, 'vgcx', '4')
# (244, 'zbx', -1)
# (14, 'jjz', -1)
# (63, 'czr', -1)
# (231, 'jm', -1)
# (108, 'kblc', -1)
# (101, 'rkjn', -1)
# (57, 'ml', '6')
# (28, 'ljf', -1)
# (37, 'qblf', -1)
# (94, 'lzx', '5')
# (244, 'nf', -1)
# (62, 'mgz', '4')
# (165, 'hql', -1)
# (217, 'gr', -1)
# (65, 'fnkb', -1)
# (118, 'vpp', '7')
# (152, 'vpr', '8')
# (234, 'hb', '4')
# (21, 'sqq', '1')
# (152, 'xlt', -1)
# (74, 'mm', -1)
# (104, 'vgcx', '6')
# (153, 'sf', -1)
# (152, 'dt', -1)
# (118, 'tb', -1)
# (221, 'sj', '5')
# (162, 'vjvl', -1)
# (154, 'cg', '8')
# (60, 'fhn', -1)
# (191, 'nmd', '4')
# (230, 'kk', '6')
# (184, 'fr', -1)
# (43, 'mvrzl', '8')
# (210, 'nd', -1)
# (211, 'cpp', -1)
# (145, 'gvd', -1)
# (166, 'crmd', '2')
# (180, 'jxnd', '8')
# (187, 'sh', -1)
# (225, 'ttgpr', -1)
# (176, 'kqd', -1)
# (62, 'zmg', '8')
# (51, 'rmtp', '1')
# (153, 'sf', '8')
# (133, 'vcl', '2')
# (65, 'xnk', -1)
# (45, 'zmf', '7')
# (135, 'tc', -1)
# (142, 'mq', -1)
# (109, 'rpvcr', -1)
# (161, 'jvdm', -1)
# (171, 'ch', -1)
# (104, 'vgcx', '8')
# (188, 'ddt', -1)
# (5, 'kpz', -1)
# (161, 'jvdm', -1)
# (20, 'bjhvj', -1)
# (200, 'vr', -1)
# (149, 'ftk', -1)
# (30, 'vh', '1')
# (184, 'fr', '8')
# (218, 'lvx', -1)
# (29, 'vqtr', -1)
# (85, 'kvd', '9')
# (163, 'tkd', '9')
# (6, 'zppl', -1)
# (101, 'mrzl', '3')
# (191, 'nmd', -1)
# (62, 'hbt', '8')
# (192, 'frzn', '6')
# (252, 'zbtzr', '4')
# (227, 'fkr', -1)
# (18, 'vnn', '2')
# (206, 'pzd', -1)
# (8, 'km', '5')
# (28, 'pqk', '6')
# (247, 'kl', -1)
# (114, 'fff', -1)
# (111, 'krhj', -1)
# (194, 'njj', -1)
# (28, 'ht', -1)
# (204, 'rz', '5')
# (92, 'pff', '1')
# (240, 'zfp', '8')
# (116, 'pkqx', '6')
# (161, 'hzbm', '2')
# (184, 'tgm', -1)
# (97, 'svdt', -1)
# (155, 'zggqr', '4')
# (201, 'gb', -1)
# (90, 'btd', '5')
# (201, 'vc', '4')
# (150, 'rpqs', '3')
# (99, 'ndvk', -1)
# (68, 'rhj', '1')
# (102, 'mxnc', -1)
# (20, 'vlr', '5')
# (249, 'nklsq', '5')
# (4, 'hpjb', -1)
# (97, 'svdt', -1)
# (226, 'nt', -1)
# (211, 'cpp', -1)
# (180, 'jxnd', -1)
# (54, 'xxf', '2')
# (214, 'hsk', -1)
# (7, 'tsld', -1)
# (6, 'qpkz', '3')
# (146, 'prvz', '9')
# (149, 'dlmfb', '7')
# (211, 'cpp', -1)
# (174, 'lrhtt', -1)
# (64, 'phxp', -1)
# (146, 'vvf', '7')
# (101, 'dq', -1)
# (249, 'jhmz', -1)
# (252, 'jlf', '8')
# (249, 'jhmz', '3')
# (161, 'hzbm', -1)
# (236, 'tx', -1)
# (165, 'vlpc', -1)
# (239, 'tcx', '3')
# (146, 'sblkv', '8')
# (149, 'ftk', -1)
# (94, 'zd', -1)
# (210, 'nd', '2')
# (32, 'qlc', '7')
# (139, 'ctxhnf', '3')
# (2, 'mqfxv', '4')
# (174, 'bff', '3')
# (55, 'ccq', -1)
# (212, 'zz', '1')
# (147, 'ktbr', -1)
# (28, 'pqk', '5')
# (7, 'tsld', -1)
# (75, 'gzsvq', -1)
# (26, 'tkk', '1')
# (52, 'hzr', -1)
# (205, 'tcv', -1)
# (135, 'tc', '6')
# (188, 'fpf', '1')
# (46, 'pcjxqx', '1')
# (168, 'jzd', '1')
# (110, 'ks', '6')
# (158, 'gjm', '7')
# (16, 'nxjzf', -1)
# (29, 'vqtr', -1)
# (15, 'xmj', '3')
# (218, 'ft', -1)
# (3, 'pc', '5')
# (234, 'gs', '9')
# (86, 'rd', '3')
# (249, 'nklsq', '2')
# (62, 'zmg', '1')
# (217, 'gr', -1)
# (94, 'jt', -1)
# (175, 'jdq', '8')
# (109, 'rpvcr', -1)
# (137, 'qlxt', '9')
# (236, 'tx', -1)
# (70, 'pv', '1')
# (159, 'rcj', -1)
# (180, 'jxnd', -1)
# (55, 'hxg', '3')
# (134, 'rzqgr', -1)
# (185, 'fc', -1)
# (17, 'cn', '2')
# (56, 'nj', -1)
# (180, 'xbz', '7')
# (146, 'sblkv', '9')
# (165, 'vlpc', '7')
# (137, 'kqbk', -1)
# (70, 'xjd', -1)
# (154, 'cfq', -1)
# (210, 'nkbmj', -1)
# (194, 'njj', -1)
# (32, 'qlc', '6')
# (97, 'svdt', -1)
# (11, 'kld', -1)
# (8, 'km', -1)
# (57, 'tmx', -1)
# (86, 'rd', '8')
# (236, 'tx', -1)
# (246, 'qrs', -1)
# (70, 'pv', '7')
# (244, 'nf', -1)
# (155, 'gnrt', '6')
# (240, 'zfp', '8')
# (135, 'qkk', '1')
# (23, 'mj', '9')
# (136, 'rv', '1')
# (67, 'fvgqlc', '6')
# (132, 'vn', -1)
# (226, 'nt', -1)
# (109, 'rpvcr', -1)
# (145, 'gvd', '5')
# (152, 'td', -1)
# (101, 'vxjjs', -1)
# (102, 'cs', '5')
# (146, 'sblkv', -1)
# (147, 'lckfs', '6')
# (165, 'hql', -1)
# (74, 'mm', -1)
# (147, 'xk', -1)
# (249, 'jhmz', '8')
# (60, 'xrr', -1)
# (28, 'cpqx', -1)
# (249, 'nklsq', -1)
# (255, 'tsx', -1)
# (6, 'lbsmh', -1)
# (129, 'dmfz', '5')
# (188, 'fpf', '5')
# (158, 'np', '2')
# (207, 'ggvptg', -1)
# (63, 'gx', '4')
# (35, 'cbgltg', '6')
# (122, 'ztl', '8')
# (190, 'pn', '3')
# (85, 'kvd', -1)
# (203, 'sx', -1)
# (97, 'gz', '5')
# (92, 'jrztr', -1)
# (47, 'gh', -1)
# (54, 'xxf', -1)
# (113, 'szt', '9')
# (154, 'cg', -1)
# (177, 'bcl', '2')
# (63, 'czr', -1)
# (103, 'qv', -1)
# (29, 'vqtr', '3')
# (126, 'dvhvf', -1)
# (236, 'tx', -1)
# (81, 'gj', '7')
# (172, 'bj', '7')
# (234, 'hpr', '8')
# (163, 'tkd', -1)
# (21, 'sqq', '1')
# (158, 'ldfh', '6')
# (62, 'mgz', '6')
# (152, 'td', -1)
# (162, 'jx', '8')
# (217, 'gr', -1)
# (3, 'qdhf', '9')
# (231, 'lkp', -1)
# (107, 'cbv', -1)
# (231, 'jm', '1')
# (188, 'bz', '8')
# (145, 'gvd', '2')
# (130, 'ljl', '2')
# (240, 'rvh', '1')
# (164, 'xl', -1)
# (64, 'phxp', '6')
# (46, 'kkh', -1)
# (121, 'bkht', '9')
# (173, 'lshv', '3')
# (102, 'cs', '6')
# (70, 'pv', -1)
# (239, 'tcx', -1)
# (86, 'lthn', '8')
# (147, 'lckfs', -1)
# (153, 'sf', '8')
# (52, 'kfc', '9')
# (36, 'pt', -1)
# (171, 'ch', '6')
# (34, 'rp', -1)
# (28, 'ht', -1)
# (168, 'fb', '5')
# (180, 'jxnd', '9')
# (34, 'grcdlv', -1)
# (227, 'fkr', '1')
# (157, 'xbpsnb', -1)
# (164, 'jkhg', -1)
# (72, 'crs', '3')
# (157, 'xbpsnb', -1)
# (54, 'pf', '8')
# (152, 'vfnjd', -1)
# (41, 'lm', -1)
# (113, 'szt', '1')
# (101, 'mrzl', '6')
# (52, 'drtj', '5')
# (85, 'kvd', '7')
# (44, 'jb', -1)
# (228, 'lnj', -1)
# (94, 'jt', -1)
# (130, 'rjbd', '4')
# (34, 'rp', '5')
# (97, 'gz', '9')
# (56, 'ttcmzv', -1)
# (194, 'bssj', '8')
# (3, 'qdhf', '3')
# (254, 'msn', '3')
# (217, 'grp', '3')
# (62, 'hv', -1)
# (55, 'ccq', '7')
# (117, 'shj', -1)
# (234, 'hb', -1)
# (109, 'rpvcr', -1)
# (182, 'ckx', -1)
# (30, 'fx', -1)
# (28, 'ht', '8')
# (158, 'gjm', '4')
# (31, 'bkr', -1)
# (153, 'vpc', '9')
# (23, 'gxh', -1)
# (94, 'jt', '6')
# (30, 'gg', -1)
# (134, 'tr', '5')
# (3, 'pc', -1)
# (204, 'rz', '7')
# (51, 'rq', '8')
# (238, 'ltn', -1)
# (11, 'hs', -1)
# (123, 'qgc', '9')
# (123, 'qgc', '5')
# (20, 'pd', '3')
# (41, 'lm', -1)
# (166, 'crmd', '6')
# (223, 'qn', '9')
# (98, 'jdqmf', -1)
# (102, 'znkc', -1)
# (226, 'hxb', -1)
# (13, 'gbt', -1)
# (102, 'cgl', '4')
# (144, 'jbd', -1)
# (146, 'lkk', '3')
# (252, 'bbph', '6')
# (121, 'bg', -1)
# (114, 'hj', -1)
# (249, 'zmr', '6')
# (246, 'gdglbv', -1)
# (224, 'pp', -1)
# (137, 'str', -1)
# (37, 'brqld', '6')
# (250, 'hr', '9')
# (72, 'crs', '2')
# (247, 'zm', '7')
# (236, 'tx', '4')
# (230, 'cqrp', -1)
# (64, 'vj', '8')
# (137, 'qlxt', '3')
# (52, 'hzr', -1)
# (109, 'lq', '8')
# (24, 'gsdj', -1)
# (178, 'mkj', '9')
# (34, 'dscx', -1)
# (86, 'rd', '9')
# (200, 'kkb', -1)
# (34, 'grcdlv', -1)
# (72, 'mgdzf', -1)
# (227, 'jcv', '6')
# (153, 'dtq', '7')
# (238, 'ltn', '4')
# (24, 'll', -1)
# (114, 'gsh', '8')
# (114, 'gsh', -1)
# (191, 'nmd', -1)
# (252, 'zbtzr', -1)
# (82, 'vhppt', -1)
# (242, 'vlp', '3')
# (96, 'cmthnv', '8')
# (51, 'pkx', '5')
# (211, 'cpp', '1')
# (101, 'vxjjs', -1)
# (222, 'tdf', -1)
# (63, 'cbnfv', -1)
# (130, 'ljl', -1)
# (242, 'vlp', '8')
# (16, 'nxjzf', '4')
# (37, 'grgrps', '5')
# (147, 'pbq', '4')
# (145, 'brscg', -1)
# (252, 'bbph', '8')
# (116, 'vck', '8')
# (135, 'qkk', '7')
# (190, 'bvf', '3')
# (23, 'mj', -1)
# (168, 'fb', -1)
# (194, 'zqg', '7')
# (162, 'kg', -1)
# (163, 'tkd', '1')
# (44, 'xgfjsz', '5')
# (144, 'vxb', -1)
# (33, 'qjv', -1)
# (247, 'pdjgr', '9')
# (176, 'kqd', -1)
# (182, 'ckx', -1)
# (162, 'vjvl', -1)
# (154, 'cfq', -1)
# (22, 'fhnz', -1)
# (174, 'lrhtt', '9')
# (21, 'nlk', -1)
# (53, 'qd', -1)
# (80, 'hh', -1)
# (228, 'lnj', -1)
# (54, 'pf', -1)
# (149, 'dlmfb', -1)
# (195, 'kx', -1)
# (29, 'vqtr', '9')
# (189, 'sdv', '8')
# (99, 'ndvk', -1)
# (37, 'grgrps', '5')
# (42, 'hglmnt', -1)
# (102, 'cgl', '3')
# (101, 'mrzl', -1)
# (126, 'lr', '4')
# (234, 'czm', -1)
# (85, 'kvd', -1)
# (46, 'vx', '5')
# (150, 'rpqs', -1)
# (188, 'ddt', -1)
# (176, 'njx', -1)
# (90, 'btd', -1)
# (74, 'tbdzv', '4')
# (41, 'xlmx', -1)
# (67, 'fvgqlc', '6')
# (249, 'zmr', '4')
# (178, 'zx', '7')
# (28, 'xzmm', '8')
# (174, 'vll', -1)
# (113, 'szt', -1)
# (252, 'bbph', -1)
# (35, 'cbgltg', -1)
# (127, 'rpm', '4')
# (220, 'th', '7')
# (55, 'hxg', '9')
# (190, 'pn', -1)
# (28, 'xzmm', -1)
# (223, 'qn', -1)
# (76, 'zr', -1)
# (194, 'bssj', '9')
# (132, 'gm', -1)
# (74, 'tbdzv', -1)
# (215, 'djlm', '1')
# (121, 'bkht', '9')
# (92, 'kzmhkg', '6')
# (190, 'lbld', '1')
# (254, 'msn', '8')
# (220, 'th', '9')
# (217, 'grp', '9')
# (45, 'zmf', -1)
# (132, 'gm', '8')
# (32, 'qlc', -1)
# (101, 'zcrf', -1)
# (54, 'pf', -1)
# (197, 'jk', '3')
# (192, 'frzn', '3')
# (17, 'cn', -1)
# (28, 'xd', '3')
# (135, 'qkk', -1)
# (42, 'zp', -1)
# (64, 'vj', '6')
# (171, 'fjjtm', '9')
# (175, 'nq', '2')
# (135, 'tc', -1)
# (141, 'pgv', '2')
# (101, 'dq', '7')
# (162, 'mkffn', -1)
# (65, 'xnk', '4')
# (36, 'vmq', '1')
# (24, 'gsdj', '1')
# (194, 'hfzz', -1)
# (164, 'jkhg', '8')
# (16, 'sm', -1)
# (197, 'mxp', '7')
# (205, 'ldm', '5')
# (147, 'xk', -1)
# (48, 'jlrh', '8')
# (16, 'nxjzf', '7')
# (90, 'btd', -1)
# (126, 'dvhvf', -1)
# (14, 'fh', -1)
# (99, 'lvq', -1)
# (18, 'bp', '9')
# (6, 'qpkz', -1)
# (113, 'tdvs', -1)
# (18, 'bp', '1')
# (26, 'tkk', '9')
# (145, 'gvd', -1)
# (240, 'rvh', '5')
# (191, 'nmd', -1)
# (176, 'kqd', '3')
# (74, 'gpkh', '3')
# (178, 'mkj', -1)
# (37, 'qgm', '6')
# (131, 'mvp', '6')
# (172, 'ckqkrp', -1)
# (210, 'nkbmj', '8')
# (239, 'tcx', -1)
# (131, 'cld', '7')
# (214, 'hsk', '3')
# (194, 'bssj', '3')
# (215, 'djlm', '8')
# (130, 'xj', -1)
# (241, 'pq', '4')
# (179, 'kh', -1)
# (6, 'zppl', -1)
# (103, 'kdll', '9')
# (86, 'lthn', -1)
# (145, 'brscg', '1')
# (213, 'vgx', -1)
# (80, 'hh', -1)
# (57, 'ml', '7')
# (190, 'lbld', '5')
# (50, 'dn', -1)
# (254, 'shc', '3')
# (102, 'cs', -1)
# (162, 'mkffn', -1)
# (97, 'gz', '5')
# (77, 'jpc', '9')
# (168, 'fb', '1')
# (166, 'crmd', '3')
# (255, 'tsx', -1)
# (137, 'kqbk', '8')
# (92, 'kzmhkg', -1)
# (45, 'zmf', '1')
# (46, 'vx', '2')
# (77, 'jpc', '6')
# (101, 'dq', '4')
# (35, 'cbgltg', '4')
# (46, 'hf', -1)
# (223, 'qn', -1)
# (86, 'lthn', -1)
# (35, 'qr', -1)
# (251, 'gxdx', '6')
# (174, 'vll', -1)
# (52, 'kfc', -1)
# (165, 'vlpc', -1)
# (174, 'lrhtt', '1')
# (94, 'jt', -1)
# (247, 'kl', -1)
# (3, 'pc', -1)
# (6, 'lbsmh', -1)
# (173, 'nmr', -1)
# (221, 'sj', -1)
# (115, 'gl', '1')
# (184, 'czzq', -1)
# (77, 'kb', '1')
# (122, 'fnf', -1)
# (103, 'trq', '4')
# (94, 'kc', '6')
# (236, 'mskmt', '2')
# (129, 'gtv', '3')
# (249, 'vfm', -1)
# (18, 'vnn', -1)
# (190, 'lbld', '4')
# (101, 'sr', '7')
# (129, 'dmfz', -1)
# (138, 'dtpb', '4')
# (214, 'prt', -1)
# (24, 'gsdj', '3')
# (153, 'sf', '8')
# (153, 'vpc', -1)
# (28, 'pqk', '6')
# (188, 'fpf', '1')
# (145, 'gvd', '3')
# (237, 'sz', -1)
# (52, 'kfc', -1)
# (77, 'zc', -1)
# (89, 'gkg', -1)
# (102, 'cs', -1)
# (249, 'jhmz', -1)
# (138, 'dtpb', '2')
# (132, 'gm', '6')
# (97, 'gsg', '8')
# (6, 'zppl', '8')
# (110, 'ks', '2')
# (30, 'gg', -1)
# (36, 'vmq', -1)
# (82, 'bdkdjc', '4')
# (246, 'qrs', -1)
# (46, 'kkh', '7')
# (194, 'hfzz', '1')
# (137, 'qx', '1')
# (103, 'trq', -1)
# (16, 'nxjzf', -1)
# (190, 'bvf', -1)
# (46, 'hf', -1)
# (93, 'zs', '7')
# (192, 'frzn', -1)
# (129, 'gtv', -1)
# (237, 'ktlshg', '3')
# (219, 'fsb', '4')
# (4, 'nv', -1)
# (53, 'qd', -1)
# (145, 'gvd', '3')
# (176, 'ms', '4')
# (129, 'lzk', -1)
# (62, 'zmg', '8')
# (137, 'qlxt', '6')
# (237, 'sz', '9')
# (135, 'tc', -1)
# (153, 'vpc', -1)
# (24, 'bbt', -1)
# (45, 'zmf', '7')
# (57, 'ml', -1)
# (188, 'bz', -1)
# (162, 'vjvl', '6')
# (236, 'tx', -1)
# (217, 'gr', -1)
# (70, 'pv', -1)
# (161, 'hzbm', -1)
# (179, 'kh', -1)
# (146, 'rnr', -1)
# (205, 'bhs', '8')
# (133, 'qlx', -1)
# (81, 'vk', '6')
# (85, 'sb', '3')
# (37, 'qblf', '3')
# (145, 'gvd', '2')
# (242, 'kzbmn', '4')
# (33, 'qjv', '2')
# (30, 'fx', -1)
# (237, 'sz', '9')
# (205, 'lsn', -1)
# (36, 'vmq', '8')
# (102, 'mxnc', -1)
# (20, 'vlr', '9')
# (102, 'cgl', '4')
# (131, 'mvp', -1)
# (85, 'rs', -1)
# (201, 'fsp', -1)
# (94, 'zd', -1)
# (136, 'rv', '9')
# (166, 'phjd', '4')
# (92, 'jrztr', '5')
# (172, 'bj', '7')
# (34, 'rp', -1)
# (145, 'kf', -1)
# (185, 'fc', -1)
# (8, 'szvrqb', '1')
# (152, 'xlt', '1')
# (139, 'ctd', '9')
# (227, 'fkr', '3')
# (204, 'rz', '8')
# (62, 'hv', -1)
# (101, 'rkjn', '8')
# (241, 'bgh', -1)
# (133, 'vcl', -1)
# (173, 'bkhdt', '1')
# (129, 'dmfz', -1)
# (205, 'bhs', -1)
# (104, 'vgcx', -1)
# (74, 'mm', -1)
# (205, 'tcv', '1')
# (173, 'bkhdt', '2')
# (149, 'ftk', -1)
# (236, 'mskmt', -1)
# (12, 'hd', '8')
# (121, 'bkht', -1)
# (204, 'rz', '4')
# (64, 'vj', -1)
# (116, 'pkqx', '4')
# (174, 'zsq', -1)
# (158, 'ccdd', '4')
# (145, 'kf', '9')
# (114, 'fff', '1')
# (227, 'bqkxm', -1)
# (166, 'phjd', -1)
# (104, 'px', -1)
# (173, 'ptjlc', -1)
# (223, 'qn', '1')
# (146, 'sblkv', '4')
# (240, 'zfp', -1)
# (195, 'pflmt', -1)
# (94, 'kc', '6')
# (0, 'rn', '1')
# (197, 'jk', '5')
# (127, 'rpm', -1)
# (226, 'hxb', -1)
# (130, 'xj', -1)
# (28, 'cpqx', -1)
# (238, 'dj', '6')
# (230, 'rdhshm', -1)
# (8, 'km', -1)
# (144, 'zv', '8')
# (18, 'bp', -1)
# (145, 'kf', -1)
# (137, 'qx', -1)
# (31, 'xkxt', '7')
# (141, 'pgv', '1')
# (129, 'dmfz', -1)
# (65, 'xnk', -1)
# (102, 'mxnc', -1)
# (14, 'jjz', -1)
# (44, 'jb', -1)
# (222, 'ck', '6')
# (189, 'sdv', '1')
# (48, 'jlrh', -1)
# (249, 'nklsq', -1)
# (198, 'zzhj', -1)
# (234, 'czm', -1)
# (72, 'mgdzf', '7')
# (36, 'pt', '9')
# (11, 'kld', -1)
# (216, 'ldsphm', '7')
# (30, 'gg', '9')
# (147, 'pbq', '8')
# (247, 'zm', '7')
# (145, 'kf', -1)
# (244, 'zbx', -1)
# (171, 'fjjtm', -1)
# (49, 'tm', -1)
# (0, 'rn', -1)
# (101, 'mrzl', '5')
# (117, 'qlh', -1)
# (147, 'lckfs', -1)
# (242, 'msbjv', -1)
# (28, 'pqk', -1)
# (176, 'ms', -1)
# (215, 'djlm', -1)
# (118, 'tb', -1)
# (184, 'blj', -1)
# (201, 'fsp', '5')
# (93, 'zs', -1)
# (144, 'zv', -1)
# (136, 'rv', -1)
# (60, 'xrr', -1)
# (46, 'kkh', '8')
# (254, 'msn', '5')
# (5, 'kpz', -1)
# (172, 'ckqkrp', '3')
# (30, 'gg', -1)
# (29, 'vqtr', -1)
# (82, 'bdkdjc', '1')
# (144, 'ld', '1')
# (28, 'mhg', -1)
# (29, 'gv', -1)
# (57, 'tmx', '1')
# (210, 'kmtv', '1')
# (197, 'ngp', -1)
# (56, 'nj', -1)
# (234, 'hpr', -1)
# (22, 'nfzh', -1)
# (166, 'phjd', -1)
# (144, 'zv', -1)
# (230, 'zl', '1')
# (175, 'mnd', -1)
# (23, 'tdlc', '2')
# (103, 'kdll', '7')
# (182, 'ckx', '7')
# (158, 'np', -1)
# (224, 'pp', '3')
# (231, 'jm', -1)
# (205, 'tcv', -1)
# (201, 'gb', '8')
# (242, 'vlp', -1)
# (239, 'tcx', '3')
# (152, 'td', '5')
# (147, 'xk', '3')
# (201, 'gb', '4')
# (82, 'bdkdjc', -1)
# (144, 'zv', '3')
# (152, 'dt', '7')
# (10, 'xr', '3')
# (121, 'ggqj', -1)
# (21, 'nlk', -1)
# (37, 'brqld', '1')
# (218, 'lvx', '2')
# (181, 'lpgr', '1')
# (103, 'kdll', -1)
# (155, 'gnrt', -1)
# (122, 'fnf', -1)
# (12, 'hd', '3')
# (205, 'ldm', '8')
# (225, 'ttgpr', '7')
# (146, 'rnr', -1)
# (254, 'dz', '2')
# (116, 'vck', -1)
# (142, 'zdrpn', -1)
# (226, 'nt', '4')
# (181, 'lpgr', -1)
# (172, 'ckqkrp', -1)
# (147, 'lckfs', -1)
# (158, 'ccdd', '5')
# (146, 'prvz', '3')
# (93, 'zs', -1)
# (203, 'sx', -1)
# (15, 'xmj', '4')
# (247, 'zm', -1)
# (17, 'cn', -1)
# (29, 'gv', '9')
# (101, 'zcrf', -1)
# (162, 'jx', '7')
# (152, 'td', '5')
# (7, 'tsld', -1)
# (11, 'hs', -1)
# (81, 'cvdt', '2')
# (186, 'dfp', '2')
# (101, 'mrzl', -1)
# (85, 'kvd', '4')
# (115, 'nsskd', '8')
# (115, 'nsskd', '4')
# (8, 'ggj', '1')
# (130, 'xj', -1)
# (155, 'qjlt', -1)
# (131, 'mvp', -1)
# (236, 'tx', '9')
# (153, 'vpc', '5')
# (218, 'ft', -1)
# (194, 'zqg', -1)
# (217, 'grp', -1)
# (63, 'cbnfv', '8')
# (60, 'xrr', '4')
# (123, 'gjz', -1)
# (149, 'dlmfb', -1)
# (5, 'kpz', -1)
# (29, 'vqtr', '8')
# (180, 'pcgj', '7')
# (101, 'sr', '9')
# (141, 'pgv', -1)
# (227, 'fkr', '4')
# (118, 'vpp', -1)
# (37, 'grgrps', '4')
# (44, 'jb', -1)
# (173, 'bkhdt', '3')
# (213, 'vgx', -1)
# (60, 'xrr', -1)
# (155, 'zggqr', '2')
# (102, 'cs', -1)
# (46, 'kkh', '5')
# (237, 'sz', '3')
# (117, 'shj', '1')
# (23, 'mj', '9')
# (188, 'fpf', -1)
# (98, 'jdqmf', -1)
# (92, 'pff', -1)
# (110, 'ks', -1)
# (6, 'zppl', -1)
# (171, 'ch', '1')
# (63, 'gx', '8')
# (89, 'gkg', -1)
# (238, 'ltn', '8')
# (206, 'pzd', -1)
# (172, 'ckqkrp', -1)
# (154, 'cfq', '5')
# (81, 'gj', '4')
# (175, 'nq', -1)
# (115, 'nsskd', '4')
# (205, 'dbznbm', -1)
# (205, 'ldm', '8')
# (0, 'pld', '5')
# (6, 'lbsmh', -1)
# (41, 'lm', '7')
# (153, 'sf', '3')
# (20, 'pd', '2')
# (226, 'hxb', '6')
# (237, 'ktlshg', -1)
# (192, 'pkkj', '1')
# (238, 'dj', '9')
# (230, 'rdhshm', -1)
# (122, 'vlx', '7')
# (28, 'cpqx', '4')
# (210, 'kmtv', -1)
# (20, 'pd', -1)
# (46, 'vx', '6')
# (205, 'bhs', -1)
# (172, 'ckqkrp', '2')
# (104, 'px', '8')
# (200, 'kkb', -1)
# (24, 'gsdj', -1)
# (153, 'sf', -1)
# (205, 'bhs', -1)
# (162, 'mkffn', '4')
# (3, 'qdhf', -1)
# (137, 'cf', '4')
# (130, 'xj', -1)
# (202, 'fd', '7')
# (161, 'hzbm', -1)
# (134, 'tr', '7')
# (158, 'ccdd', -1)
# (172, 'xvksp', '4')
# (215, 'nvc', -1)
# (110, 'rpl', -1)
# (155, 'gnrt', '2')
# (104, 'px', -1)
# (4, 'hpjb', '9')
# (225, 'ttgpr', '1')
# (147, 'lckfs', '2')
# (32, 'qlc', -1)
# (7, 'tsld', '3')
# (27, 'xs', -1)
# (94, 'kc', -1)
# (130, 'hz', '4')
# (121, 'ggqj', -1)
# (65, 'fnkb', -1)
# (243, 'flq', -1)
# (43, 'lkt', -1)
# (46, 'hf', '9')
# (198, 'zzhj', '7')
# (152, 'vpr', '8')
# (174, 'bff', -1)
# (158, 'np', '9')
# (43, 'lkt', '1')
# (103, 'trq', '1')
# (174, 'zsq', -1)
# (64, 'phxp', '2')
# (171, 'dds', -1)
# (101, 'zcrf', '4')
# (163, 'tkd', -1)
# (162, 'mkffn', '2')
# (21, 'nlk', '6')
# (203, 'sx', '6')
# (158, 'ldfh', '3')
# (64, 'vj', -1)
# (137, 'qlxt', -1)
# (102, 'rlgq', -1)
# (86, 'rd', '9')
# (122, 'ztl', -1)
# (101, 'sr', '9')
# (82, 'bdkdjc', '5')
# (129, 'dmfz', -1)
# (146, 'rnr', '7')
# (23, 'mj', -1)
# (179, 'kh', -1)
# (234, 'czm', '4')
# (179, 'kh', '2')
# (62, 'mgz', -1)
# (30, 'vh', -1)
# (92, 'jrztr', '7')
# (250, 'xb', -1)
# (210, 'nd', -1)
# (146, 'vvf', '3')
# (146, 'sblkv', '9')
# (210, 'kmtv', '1')
# (94, 'zd', '8')
# (6, 'grgf', -1)
# (171, 'ch', -1)
# (117, 'shj', -1)
# (109, 'lq', '6')
# (193, 'nkh', '9')
# (182, 'ckx', -1)
# (144, 'zv', -1)
# (46, 'kkh', -1)
# (203, 'xchx', '4')
# (48, 'jlrh', -1)
# (137, 'cf', -1)
# (60, 'fhn', '2')
# (237, 'ktlshg', '1')
# (236, 'bvfn', -1)
# (213, 'zkhx', -1)
# (221, 'sj', '1')
# (10, 'xbp', '6')
# (230, 'rdhshm', '8')
# (35, 'cbgltg', '2')
# (103, 'trq', '1')
# (250, 'hr', -1)
# (133, 'mtt', '4')
# (176, 'tpgzk', -1)
# (20, 'bjhvj', -1)
# (14, 'jjz', '1')
# (23, 'gxh', '7')
# (223, 'rzcmqb', -1)
# (195, 'kx', '3')
# (172, 'ckqkrp', '3')
# (129, 'dmfz', '6')
# (6, 'lz', '6')
# (10, 'xr', -1)
# (102, 'rlgq', '9')
# (154, 'cfq', -1)
# (0, 'rn', -1)
# (174, 'qvg', '6')
# (152, 'td', '6')
# (117, 'tq', -1)
# (162, 'kg', -1)
# (121, 'sksgsn', -1)
# (113, 'tdvs', '4')
# (252, 'zbtzr', -1)
# (247, 'pdjgr', '7')
# (102, 'mxnc', -1)
# (197, 'pcr', -1)
# (193, 'nvxng', '1')
# (189, 'sdv', -1)
# (110, 'ks', '7')
# (28, 'pqk', -1)
# (29, 'gv', -1)
# (122, 'fnf', -1)
# (174, 'zsq', -1)
# (142, 'zdrpn', -1)
# (54, 'pf', '5')
# (45, 'pql', '1')
# (63, 'czr', -1)
# (103, 'kdll', -1)
# (52, 'kfc', '7')
# (207, 'ggvptg', '7')
# (1, 'sdz', '3')
# (226, 'nt', -1)
# (161, 'jvdm', '8')
# (117, 'shj', -1)
# (57, 'tng', -1)
# (10, 'xr', '6')
# (234, 'gs', -1)
# (6, 'lz', '7')
# (230, 'zl', '1')
# (205, 'lsn', '9')
# (145, 'brscg', -1)
# (153, 'sf', -1)
# (147, 'gth', '6')
# (249, 'zmr', -1)
# (237, 'ktlshg', '4')
# (34, 'rp', '2')
# (201, 'vc', '7')
# (24, 'll', '9')
# (149, 'dlmfb', '5')
# (213, 'xcz', -1)
# (51, 'pkx', -1)
# (24, 'bbt', -1)
# (170, 'kgh', -1)
# (244, 'zbx', -1)
# (244, 'xvf', '6')
# (210, 'nkbmj', -1)
# (162, 'jx', -1)
# (184, 'fr', -1)
# (249, 'jhmz', -1)
# (101, 'sr', '2')
# (72, 'gmcq', -1)
# (63, 'cbnfv', -1)
# (13, 'zkh', -1)
# (34, 'rp', -1)
# (24, 'bbt', -1)
# (252, 'bbph', '1')
# (236, 'bvfn', '9')
# (162, 'kg', '8')
# (144, 'zv', -1)
# (155, 'qjlt', '1')
# (8, 'km', '3')
# (6, 'lbsmh', -1)
# (172, 'lrn', -1)
# (142, 'zdrpn', -1)
# (197, 'ngp', -1)
# (130, 'ljl', '8')
# (174, 'bff', -1)
# (22, 'nfzh', -1)
# (28, 'mhg', -1)
# (10, 'xr', '6')
# (147, 'ktbr', -1)
# (28, 'pqk', -1)
# (145, 'kf', -1)
# (137, 'str', '8')
# (231, 'lkp', '1')
# (104, 'px', -1)
# (228, 'lnj', -1)
# (22, 'fhnz', -1)
# (222, 'ck', '6')
# (152, 'vfnjd', '4')
# (122, 'fnf', '7')
# (64, 'phxp', '4')
# (121, 'ggqj', -1)
# (223, 'qn', '2')
# (225, 'ttgpr', '7')
# (6, 'lbsmh', '5')
# (30, 'fx', '4')
# (252, 'jlf', -1)
# (66, 'dfx', '8')
# (181, 'lpgr', '8')
# (158, 'cbfc', '2')
# (210, 'nd', -1)
# (144, 'zv', -1)
# (158, 'np', '3')
# (62, 'hbt', '7')
# (129, 'gtv', '7')
# (33, 'qjv', '5')
# (6, 'qpkz', -1)
# (55, 'hxg', -1)
# (190, 'pn', -1)
# (147, 'gth', -1)
# (11, 'hs', '3')
# (200, 'kkb', '9')
# (35, 'cbgltg', '4')
# (116, 'pkqx', '6')
# (82, 'bdkdjc', '3')
# (142, 'rqhc', '4')
# (227, 'jcv', -1)
# (152, 'dt', -1)
# (194, 'zqg', -1)
# (158, 'cbfc', -1)
# (152, 'vpr', '1')
# (86, 'lthn', -1)
# (180, 'xbz', -1)
# (130, 'ljl', -1)
# (238, 'dj', '8')
# (31, 'xkxt', '5')
# (213, 'vgx', '8')
# (60, 'xrr', -1)
# (237, 'sz', '7')
# (33, 'qjv', '1')
# (179, 'kh', -1)
# (81, 'gj', '3')
# (201, 'fsp', -1)
# (158, 'gjm', -1)
# (157, 'xbpsnb', -1)
# (231, 'lkp', -1)
# (26, 'dlj', '4')
# (142, 'rqhc', -1)
# (144, 'jbd', -1)
# (30, 'fx', -1)
# (185, 'fc', '2')
# (48, 'jlrh', -1)
# (101, 'dq', -1)
# (59, 'kp', '9')
# (28, 'pqk', '3')
# (52, 'kfc', -1)
# (184, 'blj', -1)
# (44, 'jb', '2')
# (153, 'cv', '9')
# (177, 'ptncqk', '5')
# (3, 'pc', '2')
# (118, 'tb', -1)
# (205, 'bhs', -1)
# (222, 'ck', '7')
# (246, 'gdglbv', '1')
# (250, 'hr', -1)
# (135, 'tc', -1)
# (29, 'vqtr', '3')
# (214, 'hsk', -1)
# (153, 'cv', -1)
# (49, 'tm', -1)
# (190, 'bvf', '6')
# (129, 'lzk', '9')
# (108, 'kblc', -1)
# (152, 'vpr', '4')
# (171, 'fjjtm', '5')
# (171, 'fjjtm', -1)
# (2, 'mqfxv', -1)
# (0, 'rn', -1)
# (137, 'str', -1)
# (74, 'tbdzv', -1)
# (159, 'rcj', -1)
# (249, 'zmr', '5')
# (138, 'dtpb', -1)
# (6, 'qpkz', -1)
# (172, 'ckqkrp', '5')
# (146, 'sblkv', -1)
# (90, 'btd', -1)
# (24, 'bbt', '6')
# (36, 'vmq', -1)
# (114, 'hj', '1')
# (37, 'grgrps', '7')
# (102, 'cgl', '8')
# (70, 'xjd', '5')
# (24, 'bbt', -1)
# (241, 'pq', -1)
# ...
# (243, 'cxhp', -1)
# (155, 'gnrt', -1)
# (98, 'jdqmf', -1)
# (91, 'fkj', '5')
# (251, 'gxdx', -1)
# (133, 'qlx', -1)
# (234, 'hb', '6')
# (94, 'xhqbpk', '8')
# (189, 'bk', '8')
# (92, 'jrztr', '3')
# (103, 'kdll', '7')
# (234, 'gs', -1)
# (101, 'sr', '6')
# (201, 'vc', '9')
# (249, 'vfm', '1')
# (141, 'pgv', -1)
# (197, 'pcr', -1)
# (98, 'gk', -1)
# (91, 'fkj', '4')
# (178, 'zx', '6')
# (147, 'xk', -1)
# (48, 'pjss', -1)
# (188, 'pkq', -1)
# (52, 'hzr', '3')
# (164, 'xl', -1)
# (184, 'czzq', -1)
# (35, 'qr', -1)
# (76, 'zr', -1)
# (250, 'xb', '1')
# (185, 'fc', -1)
# (182, 'ckx', '4')
# (243, 'cxhp', '7')
# (140, 'hmbqd', '1')
# (101, 'dq', -1)
# (225, 'ttgpr', '1')
# (247, 'zm', -1)
# (136, 'rv', -1)
# (217, 'gr', -1)
# (27, 'xs', -1)
# (137, 'str', '9')
# (85, 'sb', -1)
# (135, 'qkk', -1)
# (210, 'nkbmj', '6')
# (31, 'xkxt', '6')
# (66, 'dfx', -1)
# (162, 'vjvl', -1)
# (29, 'gv', '4')
# (184, 'blj', '2')
# (211, 'cpp', '9')
# (18, 'bp', '3')
# (65, 'xnk', -1)
# (192, 'frzn', -1)
# (14, 'rlfxr', -1)
# (77, 'kb', '8')
# (201, 'fsp', -1)
# (144, 'vxb', '2')
# (137, 'kqbk', '7')
# (247, 'zm', '5')
# (236, 'bvfn', -1)
# (109, 'lq', -1)
# (215, 'mxb', '6')
# (0, 'rn', '6')
# (8, 'szvrqb', '1')
# (94, 'lzx', -1)
# (20, 'bjhvj', '4')
# (245, 'kpj', '9')
# (135, 'tc', '8')
# (157, 'xbpsnb', -1)
# (240, 'zfp', -1)
# (22, 'fhnz', '3')
# (55, 'hxg', -1)
# (63, 'cbnfv', '5')
# (176, 'ms', -1)
# (42, 'hglmnt', '4')
# (238, 'ltn', '6')
# (191, 'nmd', '8')
# (125, 'mp', '5')
# (66, 'dfx', -1)
# (238, 'dj', -1)
# (49, 'tm', '4')
# (236, 'mskmt', -1)
# (136, 'rv', '2')
# (101, 'mrzl', '6')
# (13, 'zkh', '7')
# (252, 'vf', '3')
# (50, 'dn', '5')
# (47, 'gh', -1)
# (72, 'gmcq', '5')
# (55, 'ccq', -1)
# (252, 'vf', '9')
# (242, 'qsxf', '2')
# (218, 'lvx', -1)
# (178, 'mkj', '6')
# (204, 'rz', '2')
# (130, 'xj', -1)
# (51, 'rmtp', '1')
# (252, 'vf', -1)
# (201, 'fsp', -1)
# (116, 'pkqx', -1)
# (24, 'gsdj', '8')
# (6, 'grgf', '9')
# (8, 'km', -1)
# (254, 'shc', -1)
# (94, 'zd', '1')
# (197, 'ngp', '2')
# (92, 'pff', -1)
# (246, 'qrs', '7')
# (192, 'frzn', '6')
# (6, 'grgf', -1)
# (102, 'mxnc', '7')
# (147, 'xk', '5')
# (237, 'ktlshg', '7')
# (91, 'fkj', '2')
# (157, 'xbpsnb', '9')
# (37, 'grgrps', '1')
# (156, 'sqvr', '5')
# (234, 'czm', '6')
# (98, 'jdqmf', '5')
# (20, 'vlr', '8')
# (201, 'vc', -1)
# (137, 'str', '7')
# (240, 'rvh', '2')
# (136, 'rv', -1)
# (176, 'kqd', -1)
# (3, 'qdhf', '6')
# (162, 'jx', -1)
# (115, 'gl', '2')
# (63, 'cbnfv', -1)
# (133, 'mtt', -1)
# (173, 'bkhdt', '1')
# (230, 'kk', '4')
# (28, 'cpqx', '5')
# (48, 'jlrh', -1)
# (171, 'fjjtm', -1)
# (174, 'bff', -1)
# (35, 'cbgltg', '8')
# (178, 'mkj', -1)
# (244, 'nf', -1)
# (227, 'fkr', '1')
# (101, 'vxjjs', -1)
# (112, 'xx', '3')
# (203, 'xchx', -1)
# (201, 'ppljc', -1)
# (51, 'pkx', -1)
# (152, 'vpr', -1)
# (205, 'ldm', -1)
# (152, 'vpr', '4')
# (146, 'lkk', '3')
# (55, 'ccq', '3')
# (57, 'ml', -1)
# (34, 'dscx', -1)
# (137, 'kqbk', '4')
# (201, 'gb', '6')
# (179, 'kh', '7')
# (60, 'xrr', '9')
# (30, 'fx', '8')
# (230, 'zl', -1)
# (218, 'ft', '6')
# (238, 'dj', -1)
# (34, 'grcdlv', -1)
# (62, 'mgz', -1)
# (247, 'kl', '9')
# (5, 'kpz', -1)
# (81, 'gj', '6')
# (158, 'ccdd', -1)
# (98, 'jdqmf', '6')
# (82, 'lhdz', '7')
# (224, 'pp', -1)
# (89, 'gkg', -1)
# (201, 'fsp', -1)
# (115, 'gl', -1)
# (255, 'tsx', -1)
# (135, 'qkk', -1)
# (197, 'pcr', -1)
# (240, 'zfp', '3')
# (104, 'px', '5')
# (231, 'lkp', '5')
# (96, 'cmthnv', '9')
# (224, 'pp', -1)
# (164, 'xl', '3')
# (145, 'gvd', -1)
# (85, 'kvd', '8')
# (7, 'tsld', '1')
# (28, 'mhg', '9')
# (202, 'tldf', -1)
# (242, 'kzbmn', -1)
# (4, 'nv', -1)
# (43, 'lkt', '7')
# (28, 'xd', -1)
# (231, 'lkp', -1)
# (134, 'rzqgr', '3')
# (198, 'zzhj', -1)
# (127, 'rpm', -1)
# (94, 'jt', -1)
# (6, 'grgf', -1)
# (152, 'xlt', '8')
# (161, 'hzbm', '4')
# (132, 'vn', -1)
# (178, 'tfvb', '4')
# (120, 'vnt', '9')
# (133, 'qlx', '5')
# (16, 'nxjzf', '4')
# (213, 'xcz', -1)
# (254, 'dz', '7')
# (52, 'drtj', '3')
# (184, 'fr', '8')
# (86, 'rd', -1)
# (72, 'gmcq', -1)
# (215, 'mxb', -1)
# (215, 'djlm', -1)
# (215, 'nvc', -1)
# (241, 'pq', -1)
# (63, 'ntm', '8')
# (194, 'njj', '7')
# (149, 'ftk', '3')
# (241, 'cjvn', -1)
# (180, 'jxnd', '7')
# (131, 'cld', -1)
# (86, 'rd', '3')
# (236, 'mskmt', '3')
# (82, 'bdkdjc', '2')
# (168, 'xms', -1)
# (82, 'bdkdjc', -1)
# (11, 'hs', -1)
# (247, 'kl', -1)
# (207, 'ggvptg', -1)
# (219, 'fsb', '6')
# (65, 'xnk', '3')
# (228, 'lnj', '8')
# (162, 'vjvl', '9')
# (193, 'nvxng', -1)
# (241, 'pq', '6')
# (68, 'rhj', '9')
# (142, 'zdrpn', '9')
# (87, 'dzbkl', '3')
# (126, 'lr', -1)
# (249, 'zmr', -1)
# (77, 'zc', -1)
# (55, 'ccq', -1)
# (164, 'xl', -1)
# (57, 'tng', -1)
# (126, 'lr', -1)
# (152, 'xlt', -1)
# (137, 'qx', '7')
# (249, 'zmr', '7')
# (254, 'msn', -1)
# (131, 'cld', -1)
# (224, 'pp', -1)
# (137, 'qx', '4')
# (85, 'rs', '3')
# (122, 'vlx', -1)
# (116, 'pkqx', -1)
# (121, 'ggqj', -1)
# (86, 'lthn', '6')
# (205, 'lsn', '8')
# (11, 'kld', -1)
# (201, 'fsp', -1)
# (202, 'fd', '4')
# (30, 'vh', '9')
# (35, 'qr', -1)
# (145, 'gvd', -1)
# (214, 'hsk', '5')
# (190, 'bvf', '2')
# (185, 'fc', '1')
# (155, 'gnrt', -1)
# (97, 'svdt', '1')
# (74, 'gpkh', -1)
# (91, 'pgd', -1)
# (138, 'dtpb', '2')
# (210, 'nd', -1)
# (197, 'ngp', -1)
# (42, 'zp', -1)
# (107, 'cbv', -1)
# (13, 'zkh', -1)
# (6, 'lbsmh', '1')
# (252, 'jlf', -1)
# (56, 'nj', '7')
# (203, 'xchx', '6')
# (56, 'nj', -1)
# (165, 'hql', '9')
# (31, 'xkxt', -1)
# (152, 'td', '1')
# (206, 'qm', '2')
# (201, 'ppljc', '6')
# (244, 'zbx', '9')
# (137, 'kqbk', -1)
# (2, 'xtcc', -1)
# (113, 'tdvs', -1)
# (137, 'qx', -1)
# (47, 'mfl', -1)
# (246, 'qrs', '5')
# (193, 'nvxng', -1)
# (220, 'th', '1')
# (202, 'fd', -1)
# (35, 'qr', '8')
# (37, 'qblf', '2')
# (102, 'znkc', -1)
# (63, 'ntm', '4')
# (176, 'njx', '6')
# (63, 'gx', '2')
# (74, 'tbdzv', -1)
# (171, 'fjjtm', '8')
# (158, 'gjm', '2')
# (53, 'qd', -1)
# (132, 'gm', '5')
# (94, 'zd', '7')
# (41, 'lm', '5')
# (178, 'zx', '9')
# (205, 'dbznbm', '3')
# (215, 'mxb', -1)
# (218, 'ft', -1)
# (190, 'lbld', '6')
# (45, 'pql', -1)
# (20, 'pd', -1)
# (102, 'rlgq', '8')
# (52, 'kfc', '9')
# (207, 'ggvptg', '6')
# (216, 'ldsphm', '2')
# (225, 'ttgpr', '3')
# (137, 'cf', '1')
# (29, 'gv', -1)
# (201, 'ppljc', '8')
# (250, 'hr', -1)
# (178, 'zx', -1)
# (121, 'sksgsn', -1)
# (113, 'szt', '3')
# (10, 'xr', '4')
# (195, 'pflmt', -1)
# (222, 'tdf', '8')
# (42, 'hglmnt', '6')
# (32, 'qlc', '2')
# (137, 'kqbk', '8')
# (130, 'rjbd', '7')
# (244, 'nf', -1)
# (152, 'td', '4')
# (70, 'xjd', -1)
# (18, 'bp', '5')
# (62, 'hv', -1)
# (219, 'fsb', -1)
# (173, 'lshv', '2')
# (45, 'zmf', -1)
# (92, 'kzmhkg', '1')
# (246, 'qrs', '8')
# (98, 'jdqmf', '1')
# (0, 'pld', -1)
# (162, 'vjvl', '6')
# (213, 'zkhx', -1)
# (52, 'kfc', -1)
# (236, 'bvfn', -1)
# (29, 'gv', '6')
# (200, 'vr', '7')
# (74, 'gpkh', '8')
# (97, 'gsg', '9')
# (139, 'ctxhnf', '8')
# (94, 'jt', -1)
# (44, 'xgfjsz', '3')
# (32, 'qlc', '9')
# (191, 'nmd', -1)
# (36, 'vmq', -1)
# (173, 'ptjlc', '4')
# (80, 'lxl', '8')
# (193, 'nvxng', '9')
# (252, 'zbtzr', -1)
# (254, 'tfd', '4')
# (144, 'jbd', -1)
# (109, 'lq', -1)
# (5, 'kpz', -1)
# (129, 'lzk', '9')
# (141, 'pgv', '5')
# (117, 'tq', '5')
# (87, 'fndsl', -1)
# (108, 'kblc', '9')
# (18, 'bp', -1)
# (115, 'gl', '7')
# (133, 'mtt', '7')
# (217, 'gr', -1)
# (158, 'np', -1)
# (147, 'pbq', '7')
# (155, 'zggqr', '3')
# (120, 'vnt', '8')
# (192, 'frzn', '4')
# (3, 'qdhf', -1)
# (146, 'sblkv', -1)
# (227, 'bqkxm', '6')
# (165, 'vlpc', '9')
# (101, 'sr', '6')
# (126, 'lr', '9')
# (75, 'gzsvq', '1')
# (179, 'kh', -1)
# (3, 'pc', -1)
# (11, 'xc', '6')
# (74, 'tbdzv', '8')
# (166, 'crmd', -1)
# (13, 'gbt', -1)
# (250, 'hr', '5')
# (213, 'xcz', '3')
# (54, 'xxf', '3')
# (11, 'xc', -1)
# (97, 'svdt', -1)
# (153, 'sf', -1)
# (51, 'rq', '1')
# (17, 'cn', '6')
# (102, 'znkc', '1')
# (94, 'jt', '2')
# (80, 'hh', -1)
# (28, 'xd', '5')
# (63, 'gx', '5')
# (189, 'sdv', '1')
# (145, 'gvd', -1)
# (153, 'dtq', '8')
# (122, 'vlx', -1)
# (247, 'kl', -1)
# (162, 'vjvl', '9')
# (242, 'qsxf', -1)
# (6, 'zppl', '7')
# (75, 'gzsvq', '5')
# (15, 'tk', '6')
# (254, 'tfd', '6')
# (103, 'dsp', '3')
# (168, 'xms', -1)
# (158, 'np', -1)
# (158, 'np', -1)
# (123, 'qgc', '5')
# (126, 'dvhvf', '2')
# (137, 'kqbk', '1')
# (139, 'ctxhnf', -1)
# (200, 'vr', '7')
# (92, 'rpz', '1')
# (215, 'mxb', -1)
# (215, 'djlm', '5')
# (223, 'qn', -1)
# (214, 'hsk', -1)
# (26, 'tkk', -1)
# (57, 'tng', '3')
# (87, 'dzbkl', -1)
# (149, 'ftk', '9')
# (28, 'pqk', '7')
# (123, 'gjz', '1')
# (77, 'kb', -1)
# (185, 'fc', '8')
# (219, 'fsb', '9')
# (92, 'rpz', '5')
# (7, 'tsld', '5')
# (16, 'sm', '2')
# (168, 'jzd', '6')
# (184, 'blj', -1)
# (168, 'xms', -1)
# (133, 'qlx', -1)
# (247, 'kl', '4')
# (130, 'rjbd', -1)
# (242, 'vlp', -1)
# (184, 'fr', '5')
# (86, 'knjsp', '3')
# (205, 'tcv', -1)
# (246, 'gdglbv', '2')
# (168, 'jzd', -1)
# (25, 'qrf', '6')
# (94, 'lzx', '9')
# (200, 'kkb', -1)
# (4, 'hpjb', '1')
# (162, 'vjvl', -1)
# (205, 'tcv', -1)
# (153, 'cv', -1)
# (236, 'mskmt', '6')
# (149, 'ftk', -1)
# (162, 'vjvl', -1)
# (27, 'xs', '9')
# (241, 'cjvn', -1)
# (254, 'shc', '9')
# (158, 'ccdd', '5')
# (62, 'mgz', '4')
# (3, 'qdhf', '8')
# (127, 'rpm', -1)
# (74, 'tbdzv', '7')
# (86, 'knjsp', '5')
# (133, 'mtt', '3')
# (244, 'xvf', -1)
# (32, 'qlc', '8')
# (245, 'kpj', '5')
# (230, 'rdhshm', '9')
# (15, 'xmj', -1)
# (194, 'xqsv', '4')
# (64, 'vj', '1')
# (186, 'dfp', '1')
# (117, 'tq', '9')
# (48, 'jlrh', '4')
# (252, 'bbph', -1)
# (114, 'gsh', '8')
# (188, 'fpf', -1)
# (115, 'nsskd', '1')
# (245, 'kpj', '2')
# (77, 'jpc', -1)
# (231, 'lkp', '4')
# (21, 'sqq', -1)
# (16, 'sm', '3')
# (120, 'vnt', -1)
# (66, 'dfx', -1)
# (223, 'rzcmqb', '4')
# (129, 'gtv', -1)
# (146, 'rnr', -1)
# (205, 'tcv', -1)
# (81, 'cvdt', -1)
# (135, 'tc', -1)
# (252, 'zbtzr', '2')
# (137, 'qx', -1)
# (85, 'rs', '4')
# (31, 'xkxt', '4')
# (172, 'ckqkrp', '8')
# (184, 'fr', '7')
# (201, 'gb', '4')
# (161, 'kv', '3')
# (30, 'vh', -1)
# (48, 'pjss', '4')
# (241, 'bgh', '7')
# (153, 'sf', -1)
# (227, 'fkr', '2')
# (162, 'mkffn', '2')
# (147, 'ktbr', '7')
# (144, 'vxb', '4')
# (204, 'rz', -1)
# (155, 'zggqr', -1)
# (238, 'ltn', '8')
# (241, 'cjvn', -1)
# (51, 'rmtp', -1)
# (87, 'fndsl', -1)
# (12, 'hd', '2')
# (1, 'sdz', -1)
# (147, 'ktbr', -1)
# (21, 'nlk', '8')
# (162, 'jx', '7')
# (173, 'lshv', -1)
# (230, 'cqrp', '6')
# (226, 'nt', -1)
# (249, 'zmr', '2')
# (86, 'rd', '7')
# (120, 'rf', '8')
# (197, 'ngp', -1)
# (37, 'brqld', '5')
# (94, 'jt', '6')
# (1, 'sdz', -1)
# (24, 'll', '2')
# (212, 'zz', '3')
# (131, 'mvp', '6')
# (44, 'jb', -1)
# (114, 'fff', '2')
# (20, 'bjhvj', -1)
# (43, 'lkt', '8')
# (242, 'msbjv', '7')
# (226, 'nt', '9')
# (194, 'hfzz', '7')
# (175, 'nq', -1)
# (172, 'lrn', '4')
# (197, 'mxp', '6')
# (29, 'gv', '6')
# (97, 'svdt', '1')
# (147, 'gth', '4')
# (58, 'jkzk', -1)
# (223, 'qn', -1)
# (52, 'drtj', -1)
# (47, 'gh', -1)
# (236, 'bvfn', '1')
# (46, 'kkh', '1')
# (115, 'gl', -1)
# (177, 'ptncqk', -1)
# (209, 'ns', '4')
# (134, 'tr', -1)
# (242, 'msbjv', '4')
# (48, 'jlrh', -1)
# (117, 'zsrf', '8')
# (36, 'pt', '4')
# (204, 'dh', -1)
# (120, 'rf', '3')
# (23, 'mj', -1)
# (178, 'mkj', '6')
# (91, 'pgd', '2')
# (227, 'jcv', -1)
# (147, 'lckfs', -1)
# (127, 'rpm', '5')
# (132, 'gm', -1)
# (214, 'prt', -1)
# (47, 'gh', -1)
# (237, 'sz', -1)
# (213, 'zkhx', '4')
# (103, 'dsp', -1)
# (158, 'np', -1)
# (174, 'zsq', -1)
# (110, 'rpl', '1')
# (51, 'rq', -1)
# (121, 'sksgsn', '2')
# (13, 'gbt', '8')
# (28, 'ht', -1)
# (241, 'pq', '7')
# (247, 'kl', '8')
# (2, 'mqfxv', -1)
# (252, 'zbtzr', -1)
# (35, 'qr', -1)
# (117, 'shj', -1)
# (15, 'tk', -1)
# (46, 'pcjxqx', -1)
# (249, 'nklsq', '5')
# (97, 'gz', -1)
# (59, 'kp', '2')
# (20, 'bjhvj', '8')
# (47, 'mfl', -1)
# (173, 'bkhdt', -1)
# (244, 'zbx', -1)
# (197, 'mxp', '7')
# (247, 'pdjgr', '7')
# (203, 'sx', -1)
# (194, 'xqsv', '4')
# (236, 'mskmt', '8')
# (94, 'lzx', -1)
# (29, 'gv', '8')
# (166, 'vp', '2')
# (102, 'cs', -1)
# (133, 'vcl', -1)
# (121, 'bg', '9')
# (218, 'ft', -1)
# (188, 'bz', -1)
# (57, 'ml', '4')
# (130, 'ljl', '2')
# (214, 'prt', '8')
# (153, 'cv', -1)
# (172, 'lrn', '9')
# (241, 'pq', '7')
# (130, 'xj', -1)
# (225, 'ttgpr', '4')
# (154, 'cg', '3')
# (41, 'lm', '1')
# (77, 'zc', '4')
# (198, 'zzhj', -1)
# (26, 'tkk', -1)
# (78, 'nvj', -1)
# (12, 'zmbc', '7')
# (174, 'lrhtt', '1')
# (59, 'kp', '5')
# (201, 'gb', -1)
# (173, 'lshv', -1)
# (97, 'gsg', '4')
# (112, 'xx', '2')
# (8, 'szvrqb', '3')
# (188, 'pkq', '7')
# (123, 'gjz', -1)
# (17, 'cn', '4')
# (63, 'czr', -1)
# (219, 'fsb', -1)
# (240, 'zfp', '3')
# (110, 'ks', -1)
# (86, 'lthn', -1)
# (49, 'tm', -1)
# (22, 'fhnz', '3')
# (114, 'fff', '5')
# (81, 'gj', '4')
# (52, 'drtj', '9')
# (28, 'mhg', '5')
# (154, 'cfq', '3')
# (35, 'qr', '6')
# (11, 'xc', -1)
# (131, 'cld', -1)
# (154, 'cfq', '5')
# (254, 'dz', -1)
# (242, 'qsxf', '3')
# (41, 'lm', -1)
# (219, 'fsb', -1)
# (223, 'rzcmqb', -1)
# (184, 'fr', '2')
# (72, 'gmcq', -1)
# (146, 'lkk', -1)
# (188, 'bz', -1)
# (74, 'tbdzv', '5')
# (113, 'tdvs', -1)
# (152, 'vfnjd', '8')
# (243, 'flq', '3')
# (8, 'szvrqb', '5')
# (23, 'gxh', -1)
# (201, 'vc', -1)
# (135, 'qkk', '7')
# (28, 'cpqx', -1)
# (80, 'hh', -1)
# (81, 'gj', '3')
# (13, 'zkh', '3')
# (51, 'pkx', '3')
# (144, 'vxb', '6')
# (77, 'jpc', '8')
# (99, 'ndvk', -1)
# (47, 'gh', '6')
# (172, 'bj', -1)
# (20, 'pd', '7')
# (8, 'km', -1)
# (165, 'vlpc', '6')
# (241, 'bgh', -1)
# (94, 'jt', -1)
# (122, 'fnf', '8')
# (255, 'tsx', '6')
# (249, 'vfm', -1)
# (23, 'gxh', -1)
# (246, 'gdglbv', -1)
# (130, 'ljl', '6')
# (52, 'hzr', '8')
# (215, 'djlm', -1)
# (101, 'zcrf', '2')
# (158, 'np', -1)
# (242, 'qsxf', '6')
# (225, 'ttgpr', '2')
# (205, 'bhs', -1)
# (22, 'nfzh', -1)
# (161, 'kv', '5')
# (157, 'xbpsnb', -1)
# (168, 'xms', -1)
# (249, 'zmr', -1)
# (130, 'xj', -1)
# (114, 'gsh', '1')
# (227, 'bqkxm', '3')
# (131, 'cld', -1)
# (36, 'pt', -1)
# (189, 'sdv', -1)
# (101, 'mrzl', -1)
# (21, 'nlk', -1)
# (241, 'pq', '9')
# (194, 'hfzz', '4')
# (21, 'nlk', '8')
# (114, 'fff', -1)
# (12, 'hd', '9')
# (96, 'cmthnv', '1')
# (172, 'ckqkrp', '3')
# (35, 'cbgltg', '9')
# (249, 'vfm', '7')
# (234, 'gs', '1')
# (13, 'zkh', '2')
# (158, 'ccdd', -1)
# (242, 'kzbmn', -1)
# (146, 'lkk', '6')
# (52, 'kfc', '3')
# (188, 'bz', -1)
# (56, 'nj', -1)
# (222, 'ck', -1)
# (237, 'sz', -1)
# (103, 'kdll', '1')
# (101, 'mrzl', '4')
# (215, 'djlm', -1)
# (236, 'bvfn', -1)
# (142, 'zdrpn', -1)
# (76, 'zr', '4')
# (107, 'cbv', -1)
# (28, 'mhg', -1)
# (87, 'fndsl', -1)
# (161, 'jvdm', '6')
# (137, 'cf', -1)
# (197, 'mxp', -1)
# (130, 'ljl', -1)
# (134, 'tr', '3')
# (87, 'dzbkl', -1)
# (15, 'tk', -1)
# (192, 'pkkj', '6')
# (204, 'dh', '2')
# (108, 'kblc', -1)
# (244, 'zbx', '3')
# (197, 'pcr', '6')
# (121, 'bg', -1)
# (121, 'sksgsn', -1)
# (1, 'sdz', '7')
# (102, 'mxnc', -1)
# (243, 'lpg', '2')
# (168, 'fb', -1)
# (26, 'tkk', -1)
# (215, 'mxb', '5')
# (147, 'lckfs', '9')
# (129, 'dmfz', -1)
# (162, 'jx', -1)
# (142, 'rqhc', -1)
# (94, 'kc', -1)
# (35, 'cbgltg', -1)
# (207, 'ggvptg', '1')
# (242, 'vlp', -1)
# (224, 'pp', -1)
# (36, 'pt', -1)
# (62, 'hbt', -1)
# (130, 'rjbd', -1)
# (252, 'jlf', -1)
# (12, 'zmbc', -1)
# (117, 'tq', -1)
# (4, 'hpjb', '1')
# (123, 'gjz', -1)
# (147, 'gth', -1)
# (197, 'jk', -1)
# (147, 'ktbr', '5')
# (217, 'grp', '5')
# (86, 'knjsp', -1)
# (76, 'zr', '3')
# (117, 'tq', '9')
# (205, 'tcv', -1)
# (123, 'gjz', -1)
# (243, 'flq', '2')
# (252, 'jlf', -1)
# (46, 'hf', -1)
# (173, 'bkhdt', '8')
# (238, 'bxt', '8')
# (213, 'vgx', '4')
# (78, 'nvj', -1)
# (101, 'rkjn', '1')
# (23, 'mj', -1)
# (92, 'kzmhkg', '5')
# (142, 'rqhc', '3')
# (46, 'vx', -1)
# (177, 'ptncqk', '8')
# (250, 'xb', -1)
# (142, 'mq', '2')
# (97, 'gsg', '4')
# (81, 'vk', '7')
# (116, 'pkqx', -1)
# (132, 'gm', -1)
# (85, 'sb', '8')
# (33, 'sn', -1)
# (72, 'crs', -1)
# (60, 'xrr', '7')
# (254, 'dz', '6')
# (218, 'ft', -1)
# (238, 'dj', -1)
# (218, 'ft', '7')
# (6, 'lz', '2')
# (152, 'dt', -1)
# (94, 'xhqbpk', -1)
# (132, 'gm', -1)
# (15, 'xmj', '8')
# (129, 'gtv', '4')
# (215, 'mxb', -1)
# (15, 'tk', '8')
# (103, 'qv', '2')
# (112, 'jf', '4')
# (147, 'xk', '7')
# (97, 'svdt', '6')
# (247, 'zm', -1)
# (197, 'mxp', '1')
# (81, 'gj', '1')
# (28, 'pqk', -1)
# (22, 'nfzh', '1')
# (86, 'knjsp', -1)
# (120, 'rf', '4')
# (62, 'mgz', '8')
# (86, 'knjsp', -1)
# (94, 'zd', '9')
# (51, 'pkx', '6')
# (239, 'tcx', '5')
# (153, 'sf', '4')
# (174, 'vll', -1)
# (234, 'czm', -1)
# (82, 'bdkdjc', '3')
# (78, 'nvj', '3')
# (4, 'nv', -1)
# (205, 'tcv', '4')
# (65, 'xnk', -1)
# (217, 'gr', -1)
# (94, 'jt', '5')
# (191, 'nmd', -1)
# (0, 'rn', -1)
# (220, 'th', -1)
# (72, 'gmcq', -1)
# (238, 'bxt', '2')
# (157, 'xbpsnb', -1)
# (209, 'ns', -1)
# (201, 'fsp', '2')
# (131, 'mvp', '1')
# (244, 'zbx', -1)
# (86, 'lthn', -1)
# (240, 'rvh', '5')
# (159, 'rcj', -1)
# (193, 'nvxng', '1')
# (162, 'kg', -1)
# (63, 'cbnfv', -1)
# (44, 'jb', -1)
# (72, 'crs', '2')
# (121, 'sksgsn', '3')
# (54, 'xxf', '2')
# (236, 'mskmt', '8')
# (165, 'hql', '1')
# (242, 'kzbmn', '6')
# (225, 'ttgpr', '7')
# (172, 'ckqkrp', '9')
# (109, 'rpvcr', '3')
# (14, 'jjz', -1)
# (37, 'brqld', -1)
# (213, 'xcz', -1)
# (23, 'tdlc', -1)
# (210, 'nkbmj', -1)
# (114, 'gsh', '9')
# (182, 'ckx', '9')
# (93, 'zs', -1)
# (187, 'sh', '5')
# (81, 'cvdt', -1)
# (242, 'vlp', '6')
# (115, 'gl', -1)
# (149, 'ftk', '5')
# (185, 'fc', -1)
# (137, 'qx', -1)
# (34, 'grcdlv', -1)
# (26, 'dlj', '1')
# (161, 'hzbm', -1)
# (93, 'zs', '2')
# (221, 'sj', -1)
# (136, 'rv', -1)
# (247, 'kl', '9')
# (20, 'bjhvj', -1)
# (242, 'vlp', '6')
# (52, 'hzr', -1)
# (55, 'ccq', -1)
# (66, 'dfx', -1)
# (204, 'dh', -1)
# (234, 'czm', -1)
# (144, 'ld', -1)
# (58, 'jkzk', '2')
# (85, 'rs', '8')
# (206, 'pzd', -1)
# (41, 'xlmx', -1)
# (246, 'gdglbv', -1)
# (25, 'qrf', -1)
# (67, 'fvgqlc', -1)
# (109, 'rpvcr', '8')
# (80, 'lxl', -1)
# (54, 'pf', -1)
# (173, 'lshv', -1)
# (82, 'bdkdjc', '2')
# (205, 'tcv', -1)
# (220, 'th', '4')

# %%
# Yay, can do this with regular dictionaries these days because they are ordered
boxes = [ {} for i in range(256)]

for (nbox, label, fl) in instructions:
    if fl != -1:
        boxes[nbox][label] = int(fl)
    elif label in boxes[nbox]:
        del(boxes[nbox][label])

# %%
boxes
# Out:
# [{},
#  {'sdz': 7},
#  {},
#  {'qdhf': 8},
#  {'hpjb': 1},
#  {},
#  {'lz': 2, 'lbsmh': 1, 'zppl': 7},
#  {'tsld': 5},
#  {'ggj': 1, 'szvrqb': 5},
#  {},
#  {'xbp': 6, 'xr': 4},
#  {},
#  {'hd': 9},
#  {'gbt': 8, 'zkh': 2},
#  {},
#  {'xmj': 8, 'tk': 8},
#  {'nxjzf': 4, 'sm': 3},
#  {'cn': 4},
#  {'vnn': 6},
#  {},
#  {'vlr': 8, 'pd': 7},
#  {'nlk': 8},
#  {'fhnz': 3, 'nfzh': 1},
#  {},
#  {'ll': 2, 'gsdj': 8},
#  {},
#  {'dlj': 1},
#  {'xs': 9},
#  {'xzmm': 3, 'xd': 5},
#  {'vqtr': 3, 'gv': 8},
#  {'gg': 3, 'fx': 8},
#  {'xkxt': 4},
#  {'qlc': 8},
#  {'qjv': 1},
#  {},
#  {'qr': 6},
#  {},
#  {'qgm': 6, 'qblf': 2, 'grgrps': 1},
#  {},
#  {},
#  {},
#  {},
#  {'hglmnt': 6},
#  {'mvrzl': 8, 'lkt': 8},
#  {'xgfjsz': 3},
#  {},
#  {'kkh': 1},
#  {'gh': 6},
#  {'rjt': 6, 'pjss': 4},
#  {},
#  {'dn': 5},
#  {'pkx': 6},
#  {'drtj': 9, 'kfc': 3},
#  {},
#  {'xxf': 2},
#  {},
#  {},
#  {'tmx': 1, 'tng': 3, 'ml': 4},
#  {'jkzk': 2},
#  {'kp': 5},
#  {'fhn': 2, 'xrr': 7},
#  {},
#  {'zmg': 8, 'mgz': 8},
#  {'gx': 5, 'ntm': 4},
#  {'phxp': 4, 'vj': 1},
#  {},
#  {},
#  {},
#  {'rhj': 9},
#  {},
#  {},
#  {},
#  {'crs': 2},
#  {},
#  {'mm': 1, 'gpkh': 8, 'tbdzv': 5},
#  {'gzsvq': 5},
#  {'zr': 3},
#  {'zc': 4, 'jpc': 8},
#  {'nvj': 3},
#  {},
#  {},
#  {'gj': 1, 'vk': 7},
#  {'vhppt': 1, 'lhdz': 7, 'bdkdjc': 2},
#  {},
#  {'dp': 5},
#  {'kvd': 8, 'rs': 8, 'sb': 8},
#  {'rd': 7},
#  {},
#  {},
#  {},
#  {},
#  {'fkj': 2, 'pgd': 2},
#  {'jrztr': 3, 'kzmhkg': 5, 'rpz': 5},
#  {'zs': 2},
#  {'zd': 9, 'jt': 5},
#  {},
#  {'cmthnv': 1},
#  {'gsg': 4, 'svdt': 6},
#  {'jdqmf': 1},
#  {},
#  {},
#  {'sr': 6, 'rkjn': 1, 'zcrf': 2, 'mrzl': 4},
#  {'cgl': 8, 'rlgq': 8, 'znkc': 1},
#  {'trq': 1, 'qv': 2, 'kdll': 1},
#  {'px': 5},
#  {},
#  {},
#  {},
#  {'jvtx': 4},
#  {'rpvcr': 8},
#  {'rpl': 1},
#  {},
#  {'xx': 2, 'jf': 4},
#  {'szt': 3},
#  {'gsh': 9},
#  {'nsskd': 1},
#  {'vck': 9},
#  {'zsrf': 8, 'tq': 9},
#  {'tb': 8},
#  {},
#  {'rf': 4},
#  {'bkht': 2, 'sksgsn': 3},
#  {'fnf': 8},
#  {'qgc': 5},
#  {},
#  {'mp': 5},
#  {'lr': 9, 'dvhvf': 2},
#  {'rpm': 5},
#  {},
#  {'lzk': 9, 'gtv': 4},
#  {'hz': 4},
#  {'mvp': 1},
#  {},
#  {'mtt': 3},
#  {'rzqgr': 3, 'tr': 3},
#  {'qkk': 7},
#  {},
#  {'str': 7, 'qlxt': 5, 'kqbk': 1},
#  {'dtpb': 2},
#  {'ctd': 9},
#  {'hmbqd': 1},
#  {'pgv': 5},
#  {'rqhc': 3, 'mq': 2},
#  {},
#  {'vxb': 6},
#  {},
#  {'xz': 2, 'vvf': 3, 'lkk': 6},
#  {'xk': 7, 'pbq': 7, 'lckfs': 9, 'ktbr': 5},
#  {},
#  {'dlmfb': 5, 'ftk': 5},
#  {},
#  {},
#  {'td': 4, 'vfnjd': 8, 'vpr': 4},
#  {'dtq': 8, 'sf': 4},
#  {'cg': 3, 'cfq': 5},
#  {'qjlt': 1},
#  {'sqvr': 5},
#  {},
#  {'ldfh': 3, 'cbfc': 1, 'gjm': 2},
#  {},
#  {},
#  {'jvdm': 6, 'kv': 5},
#  {'mkffn': 2},
#  {'tkd': 5},
#  {'jkhg': 8},
#  {'hql': 1, 'vlpc': 6},
#  {'vp': 2},
#  {},
#  {},
#  {},
#  {'kgh': 5},
#  {'fjjtm': 8},
#  {'xvksp': 3, 'ckqkrp': 9, 'lrn': 9},
#  {'ptjlc': 4, 'bkhdt': 8},
#  {'qvg': 9, 'lrhtt': 1},
#  {'jdq': 4},
#  {'njx': 6},
#  {'bcl': 7, 'ptncqk': 8},
#  {'tfvb': 4, 'mkj': 6},
#  {},
#  {'xbz': 2, 'jxnd': 7},
#  {'lpgr': 8},
#  {'ckx': 9},
#  {},
#  {'fr': 2},
#  {},
#  {'dfp': 1},
#  {'sh': 5},
#  {'ddt': 8, 'pkq': 7},
#  {'bk': 8},
#  {'lbld': 6, 'bvf': 2},
#  {},
#  {'pkkj': 6, 'frzn': 4},
#  {'nkh': 1, 'tcgcp': 6, 'nvxng': 1},
#  {'xqsv': 4, 'bssj': 3, 'hfzz': 4, 'njj': 7},
#  {'kx': 3},
#  {},
#  {'pcr': 6, 'mxp': 1},
#  {},
#  {},
#  {'vr': 7},
#  {'ppljc': 8, 'fsp': 2},
#  {},
#  {'fqt': 2, 'xchx': 6},
#  {},
#  {'lsn': 8, 'dbznbm': 3},
#  {'qm': 2},
#  {'ggvptg': 1},
#  {},
#  {},
#  {},
#  {'cpp': 9},
#  {'zz': 3},
#  {'vgx': 4, 'zkhx': 4},
#  {'prt': 8},
#  {},
#  {'ldsphm': 2},
#  {'grp': 5},
#  {'ft': 7},
#  {},
#  {'th': 4},
#  {},
#  {'tdf': 8},
#  {},
#  {},
#  {'ttgpr': 7},
#  {'nt': 9},
#  {'fkr': 2, 'bqkxm': 3},
#  {'lnj': 8},
#  {},
#  {'rdhshm': 9, 'kk': 4, 'cqrp': 6},
#  {'lkp': 4},
#  {},
#  {},
#  {'hb': 6, 'gs': 1},
#  {},
#  {'tx': 9, 'mskmt': 8},
#  {'ktlshg': 7},
#  {'ltn': 8, 'bxt': 2},
#  {'tcx': 5},
#  {'rvh': 5, 'zfp': 3},
#  {'pq': 9},
#  {'msbjv': 4, 'qsxf': 6, 'kzbmn': 6, 'vlp': 6},
#  {'lpg': 2, 'flq': 2, 'cxhp': 7},
#  {},
#  {'kpj': 2},
#  {'qrs': 8},
#  {'pdjgr': 7, 'kl': 9},
#  {},
#  {'nklsq': 5, 'vfm': 7},
#  {'hr': 5},
#  {},
#  {},
#  {},
#  {'tfd': 6, 'shc': 9, 'dz': 6},
#  {'tsx': 6}]

# %%
tot = 0
for i, box in enumerate(boxes):
    focus_power = 0
    for j, (k,fl) in enumerate(box.items()):
        focus_power += (i+1) * (j+1) * fl
    tot += focus_power
print(tot)
# Out:
# 268497
