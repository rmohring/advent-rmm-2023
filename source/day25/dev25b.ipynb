# %%
import sys
sys.path.append('c:/Users/rmmoh/code/rmm/advent-rmm-2023')

# %%
import numpy as np
import pandas as pd
import pydot
from operator import itemgetter

# %%
#fh = open("input25-1.dat")
fh = open("test.dat")
#fh = open("test2.dat")

lines = fh.readlines()
lines = [x.strip("\n") for x in lines]

class Graph:
    def __init__(self):
        self.edges = set()
        self.nodes = {}

    def process_str(self, initstr):
        spl = initstr.split(": ")
        source = spl[0]
        ends = spl[1].split(" ")
        for e in ends:
            self.add_edge(source, e)

    def add_edge(self, a, b):
        self.edges.add( (a,b) )

    def finalize(self):
        for (a,b) in self.edges:
            if a not in self.nodes:
                self.nodes[a] = set()
            self.nodes[a].add(b)
            if b not in self.nodes:
                self.nodes[b] = set()
            self.nodes[b].add(a)

bridges = []

def traverse(this_node, start_node, seen=None, first_step=False):
    print(start_node, this_node, "seen:", seen)
    local_seen = seen.copy()

    # Go to node and pick a new option
    next_options = [next_node for next_node in g.nodes[this_node] if next_node not in seen]
    print(f"Start: {start_node}: {this_node}... NEXT OPTIONS", next_options)

    if start_node in next_options and not first_step:
        return True
    for next_node in next_options:
        if next_node == start_node:
            print("Back to start, not a bridge")
            return True
        print(next_node)
        local_seen.append(next_node)
        not_a_bridge = traverse(next_node, start_node, seen=local_seen)
        if not_a_bridge:
            print("TRUETRUE")
            return True
        else:
            return False
    print("BLAH!")
    return False  
    
g = Graph()
for line in lines:
    g.process_str(line)

g.finalize()

# %%
# for n, ends in g.nodes.items():
#     for chk in ends:

for n in g.nodes:
    for chk in g.nodes[n]:
        if chk==n:
            continue
        print(f"Working start node: {n}; first edge {n}-{chk}")
        # Go to chk
        # Pick a new end that isn't one we've stepped on
        # Run through all permutations... 
        # if none end on "n" without hitting "chk", it's a bridge edge
        seen = [chk]
        not_a_bridge = traverse(chk, n, seen, first_step=True)
        #print(n, chk, not_a_bridge)
        if not not_a_bridge:
            bridges.append( (n, chk) )
# Out:
# Working start node: pzl; first edge pzl-nvd
# pzl nvd seen: ['nvd']
# Start: pzl: nvd... NEXT OPTIONS ['qnr', 'jqt', 'pzl', 'lhk', 'cmg']
# qnr
# pzl qnr seen: ['nvd', 'qnr']
# Start: pzl: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# rzs
# pzl rzs seen: ['nvd', 'qnr', 'rzs']
# Start: pzl: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# pzl rsh seen: ['nvd', 'qnr', 'rzs', 'rsh']
# Start: pzl: rsh... NEXT OPTIONS ['frs', 'lsr', 'pzl']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: pzl; first edge pzl-hfx
# pzl hfx seen: ['hfx']
# Start: pzl: hfx... NEXT OPTIONS ['xhk', 'bvb', 'ntq', 'rhn', 'pzl']
# xhk
# pzl xhk seen: ['hfx', 'xhk']
# Start: pzl: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn']
# bvb
# pzl bvb seen: ['hfx', 'xhk', 'bvb']
# Start: pzl: bvb... NEXT OPTIONS ['ntq', 'rhn', 'cmg']
# ntq
# pzl ntq seen: ['hfx', 'xhk', 'bvb', 'ntq']
# Start: pzl: ntq... NEXT OPTIONS ['jqt']
# jqt
# pzl jqt seen: ['hfx', 'xhk', 'bvb', 'ntq', 'jqt']
# Start: pzl: jqt... NEXT OPTIONS ['nvd', 'rhn']
# nvd
# pzl nvd seen: ['hfx', 'xhk', 'bvb', 'ntq', 'jqt', 'nvd']
# Start: pzl: nvd... NEXT OPTIONS ['qnr', 'pzl', 'lhk', 'cmg']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: pzl; first edge pzl-lsr
# pzl lsr seen: ['lsr']
# Start: pzl: lsr... NEXT OPTIONS ['frs', 'rsh', 'pzl', 'rzs', 'lhk']
# frs
# pzl frs seen: ['lsr', 'frs']
# Start: pzl: frs... NEXT OPTIONS ['qnr', 'lhk', 'rsh']
# qnr
# pzl qnr seen: ['lsr', 'frs', 'qnr']
# Start: pzl: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# rzs
# pzl rzs seen: ['lsr', 'frs', 'qnr', 'rzs']
# Start: pzl: rzs... NEXT OPTIONS ['rsh', 'cmg']
# rsh
# pzl rsh seen: ['lsr', 'frs', 'qnr', 'rzs', 'rsh']
# Start: pzl: rsh... NEXT OPTIONS ['pzl']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: pzl; first edge pzl-rsh
# pzl rsh seen: ['rsh']
# Start: pzl: rsh... NEXT OPTIONS ['rzs', 'frs', 'lsr', 'pzl']
# rzs
# pzl rzs seen: ['rsh', 'rzs']
# Start: pzl: rzs... NEXT OPTIONS ['qnr', 'cmg', 'lsr']
# qnr
# pzl qnr seen: ['rsh', 'rzs', 'qnr']
# Start: pzl: qnr... NEXT OPTIONS ['frs', 'nvd', 'cmg']
# frs
# pzl frs seen: ['rsh', 'rzs', 'qnr', 'frs']
# Start: pzl: frs... NEXT OPTIONS ['lhk', 'lsr']
# lhk
# pzl lhk seen: ['rsh', 'rzs', 'qnr', 'frs', 'lhk']
# Start: pzl: lhk... NEXT OPTIONS ['lsr', 'nvd', 'cmg']
# lsr
# pzl lsr seen: ['rsh', 'rzs', 'qnr', 'frs', 'lhk', 'lsr']
# Start: pzl: lsr... NEXT OPTIONS ['pzl']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: hfx; first edge hfx-xhk
# hfx xhk seen: ['xhk']
# Start: hfx: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn', 'hfx']
# bvb
# hfx bvb seen: ['xhk', 'bvb']
# Start: hfx: bvb... NEXT OPTIONS ['ntq', 'rhn', 'hfx', 'cmg']
# TRUETRUE
# Working start node: hfx; first edge hfx-bvb
# hfx bvb seen: ['bvb']
# Start: hfx: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx', 'cmg']
# xhk
# hfx xhk seen: ['bvb', 'xhk']
# Start: hfx: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# TRUETRUE
# Working start node: hfx; first edge hfx-ntq
# hfx ntq seen: ['ntq']
# Start: hfx: ntq... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# xhk
# hfx xhk seen: ['ntq', 'xhk']
# Start: hfx: xhk... NEXT OPTIONS ['bvb', 'jqt', 'rhn', 'hfx']
# TRUETRUE
# Working start node: hfx; first edge hfx-rhn
# hfx rhn seen: ['rhn']
# Start: hfx: rhn... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# xhk
# hfx xhk seen: ['rhn', 'xhk']
# Start: hfx: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'hfx']
# TRUETRUE
# Working start node: hfx; first edge hfx-pzl
# hfx pzl seen: ['pzl']
# Start: hfx: pzl... NEXT OPTIONS ['nvd', 'hfx', 'lsr', 'rsh']
# nvd
# hfx nvd seen: ['pzl', 'nvd']
# Start: hfx: nvd... NEXT OPTIONS ['qnr', 'jqt', 'lhk', 'cmg']
# qnr
# hfx qnr seen: ['pzl', 'nvd', 'qnr']
# Start: hfx: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# rzs
# hfx rzs seen: ['pzl', 'nvd', 'qnr', 'rzs']
# Start: hfx: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# hfx rsh seen: ['pzl', 'nvd', 'qnr', 'rzs', 'rsh']
# Start: hfx: rsh... NEXT OPTIONS ['frs', 'lsr']
# frs
# hfx frs seen: ['pzl', 'nvd', 'qnr', 'rzs', 'rsh', 'frs']
# Start: hfx: frs... NEXT OPTIONS ['lhk', 'lsr']
# lhk
# hfx lhk seen: ['pzl', 'nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk']
# Start: hfx: lhk... NEXT OPTIONS ['lsr', 'cmg']
# lsr
# hfx lsr seen: ['pzl', 'nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk', 'lsr']
# Start: hfx: lsr... NEXT OPTIONS []
# BLAH!
# Working start node: nvd; first edge nvd-qnr
# nvd qnr seen: ['qnr']
# Start: nvd: qnr... NEXT OPTIONS ['rzs', 'frs', 'nvd', 'cmg']
# rzs
# nvd rzs seen: ['qnr', 'rzs']
# Start: nvd: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# nvd rsh seen: ['qnr', 'rzs', 'rsh']
# Start: nvd: rsh... NEXT OPTIONS ['frs', 'lsr', 'pzl']
# frs
# nvd frs seen: ['qnr', 'rzs', 'rsh', 'frs']
# Start: nvd: frs... NEXT OPTIONS ['lhk', 'lsr']
# lhk
# nvd lhk seen: ['qnr', 'rzs', 'rsh', 'frs', 'lhk']
# Start: nvd: lhk... NEXT OPTIONS ['lsr', 'nvd', 'cmg']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: nvd; first edge nvd-jqt
# nvd jqt seen: ['jqt']
# Start: nvd: jqt... NEXT OPTIONS ['xhk', 'nvd', 'rhn', 'ntq']
# xhk
# nvd xhk seen: ['jqt', 'xhk']
# Start: nvd: xhk... NEXT OPTIONS ['bvb', 'ntq', 'rhn', 'hfx']
# bvb
# nvd bvb seen: ['jqt', 'xhk', 'bvb']
# Start: nvd: bvb... NEXT OPTIONS ['ntq', 'rhn', 'hfx', 'cmg']
# ntq
# nvd ntq seen: ['jqt', 'xhk', 'bvb', 'ntq']
# Start: nvd: ntq... NEXT OPTIONS ['hfx']
# hfx
# nvd hfx seen: ['jqt', 'xhk', 'bvb', 'ntq', 'hfx']
# Start: nvd: hfx... NEXT OPTIONS ['rhn', 'pzl']
# rhn
# nvd rhn seen: ['jqt', 'xhk', 'bvb', 'ntq', 'hfx', 'rhn']
# Start: nvd: rhn... NEXT OPTIONS []
# BLAH!
# Working start node: nvd; first edge nvd-pzl
# nvd pzl seen: ['pzl']
# Start: nvd: pzl... NEXT OPTIONS ['nvd', 'hfx', 'lsr', 'rsh']
# Back to start, not a bridge
# Working start node: nvd; first edge nvd-lhk
# nvd lhk seen: ['lhk']
# Start: nvd: lhk... NEXT OPTIONS ['frs', 'lsr', 'nvd', 'cmg']
# frs
# nvd frs seen: ['lhk', 'frs']
# Start: nvd: frs... NEXT OPTIONS ['qnr', 'lsr', 'rsh']
# qnr
# nvd qnr seen: ['lhk', 'frs', 'qnr']
# Start: nvd: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# TRUETRUE
# TRUETRUE
# Working start node: nvd; first edge nvd-cmg
# nvd cmg seen: ['cmg']
# Start: nvd: cmg... NEXT OPTIONS ['bvb', 'nvd', 'qnr', 'rzs', 'lhk']
# bvb
# nvd bvb seen: ['cmg', 'bvb']
# Start: nvd: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx']
# xhk
# nvd xhk seen: ['cmg', 'bvb', 'xhk']
# Start: nvd: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# jqt
# nvd jqt seen: ['cmg', 'bvb', 'xhk', 'jqt']
# Start: nvd: jqt... NEXT OPTIONS ['nvd', 'rhn', 'ntq']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: jqt; first edge jqt-xhk
# jqt xhk seen: ['xhk']
# Start: jqt: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn', 'hfx']
# bvb
# jqt bvb seen: ['xhk', 'bvb']
# Start: jqt: bvb... NEXT OPTIONS ['ntq', 'rhn', 'hfx', 'cmg']
# ntq
# jqt ntq seen: ['xhk', 'bvb', 'ntq']
# Start: jqt: ntq... NEXT OPTIONS ['hfx', 'jqt']
# TRUETRUE
# TRUETRUE
# Working start node: jqt; first edge jqt-nvd
# jqt nvd seen: ['nvd']
# Start: jqt: nvd... NEXT OPTIONS ['qnr', 'jqt', 'pzl', 'lhk', 'cmg']
# qnr
# jqt qnr seen: ['nvd', 'qnr']
# Start: jqt: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# rzs
# jqt rzs seen: ['nvd', 'qnr', 'rzs']
# Start: jqt: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# jqt rsh seen: ['nvd', 'qnr', 'rzs', 'rsh']
# Start: jqt: rsh... NEXT OPTIONS ['frs', 'lsr', 'pzl']
# frs
# jqt frs seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs']
# Start: jqt: frs... NEXT OPTIONS ['lhk', 'lsr']
# lhk
# jqt lhk seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk']
# Start: jqt: lhk... NEXT OPTIONS ['lsr', 'cmg']
# lsr
# jqt lsr seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk', 'lsr']
# Start: jqt: lsr... NEXT OPTIONS ['pzl']
# pzl
# jqt pzl seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk', 'lsr', 'pzl']
# Start: jqt: pzl... NEXT OPTIONS ['hfx']
# hfx
# jqt hfx seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk', 'lsr', 'pzl', 'hfx']
# Start: jqt: hfx... NEXT OPTIONS ['xhk', 'bvb', 'ntq', 'rhn']
# xhk
# jqt xhk seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs', 'lhk', 'lsr', 'pzl', 'hfx', 'xhk']
# Start: jqt: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: jqt; first edge jqt-rhn
# jqt rhn seen: ['rhn']
# Start: jqt: rhn... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# xhk
# jqt xhk seen: ['rhn', 'xhk']
# Start: jqt: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'hfx']
# TRUETRUE
# Working start node: jqt; first edge jqt-ntq
# jqt ntq seen: ['ntq']
# Start: jqt: ntq... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# xhk
# jqt xhk seen: ['ntq', 'xhk']
# Start: jqt: xhk... NEXT OPTIONS ['bvb', 'jqt', 'rhn', 'hfx']
# TRUETRUE
# Working start node: xhk; first edge xhk-bvb
# xhk bvb seen: ['bvb']
# Start: xhk: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx', 'cmg']
# Back to start, not a bridge
# Working start node: xhk; first edge xhk-jqt
# xhk jqt seen: ['jqt']
# Start: xhk: jqt... NEXT OPTIONS ['xhk', 'nvd', 'rhn', 'ntq']
# Back to start, not a bridge
# Working start node: xhk; first edge xhk-ntq
# xhk ntq seen: ['ntq']
# Start: xhk: ntq... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# Back to start, not a bridge
# Working start node: xhk; first edge xhk-rhn
# xhk rhn seen: ['rhn']
# Start: xhk: rhn... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# Back to start, not a bridge
# Working start node: xhk; first edge xhk-hfx
# xhk hfx seen: ['hfx']
# Start: xhk: hfx... NEXT OPTIONS ['xhk', 'bvb', 'ntq', 'rhn', 'pzl']
# Back to start, not a bridge
# Working start node: rzs; first edge rzs-qnr
# rzs qnr seen: ['qnr']
# Start: rzs: qnr... NEXT OPTIONS ['rzs', 'frs', 'nvd', 'cmg']
# Back to start, not a bridge
# Working start node: rzs; first edge rzs-rsh
# rzs rsh seen: ['rsh']
# Start: rzs: rsh... NEXT OPTIONS ['rzs', 'frs', 'lsr', 'pzl']
# Back to start, not a bridge
# Working start node: rzs; first edge rzs-cmg
# rzs cmg seen: ['cmg']
# Start: rzs: cmg... NEXT OPTIONS ['bvb', 'nvd', 'qnr', 'rzs', 'lhk']
# bvb
# rzs bvb seen: ['cmg', 'bvb']
# Start: rzs: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx']
# xhk
# rzs xhk seen: ['cmg', 'bvb', 'xhk']
# Start: rzs: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# jqt
# rzs jqt seen: ['cmg', 'bvb', 'xhk', 'jqt']
# Start: rzs: jqt... NEXT OPTIONS ['nvd', 'rhn', 'ntq']
# nvd
# rzs nvd seen: ['cmg', 'bvb', 'xhk', 'jqt', 'nvd']
# Start: rzs: nvd... NEXT OPTIONS ['qnr', 'pzl', 'lhk']
# qnr
# rzs qnr seen: ['cmg', 'bvb', 'xhk', 'jqt', 'nvd', 'qnr']
# Start: rzs: qnr... NEXT OPTIONS ['rzs', 'frs']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: rzs; first edge rzs-lsr
# rzs lsr seen: ['lsr']
# Start: rzs: lsr... NEXT OPTIONS ['frs', 'rsh', 'pzl', 'rzs', 'lhk']
# frs
# rzs frs seen: ['lsr', 'frs']
# Start: rzs: frs... NEXT OPTIONS ['qnr', 'lhk', 'rsh']
# qnr
# rzs qnr seen: ['lsr', 'frs', 'qnr']
# Start: rzs: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# TRUETRUE
# TRUETRUE
# Working start node: qnr; first edge qnr-rzs
# qnr rzs seen: ['rzs']
# Start: qnr: rzs... NEXT OPTIONS ['qnr', 'rsh', 'cmg', 'lsr']
# Back to start, not a bridge
# Working start node: qnr; first edge qnr-frs
# qnr frs seen: ['frs']
# Start: qnr: frs... NEXT OPTIONS ['qnr', 'lhk', 'lsr', 'rsh']
# Back to start, not a bridge
# Working start node: qnr; first edge qnr-nvd
# qnr nvd seen: ['nvd']
# Start: qnr: nvd... NEXT OPTIONS ['qnr', 'jqt', 'pzl', 'lhk', 'cmg']
# Back to start, not a bridge
# Working start node: qnr; first edge qnr-cmg
# qnr cmg seen: ['cmg']
# Start: qnr: cmg... NEXT OPTIONS ['bvb', 'nvd', 'qnr', 'rzs', 'lhk']
# bvb
# qnr bvb seen: ['cmg', 'bvb']
# Start: qnr: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx']
# xhk
# qnr xhk seen: ['cmg', 'bvb', 'xhk']
# Start: qnr: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# jqt
# qnr jqt seen: ['cmg', 'bvb', 'xhk', 'jqt']
# Start: qnr: jqt... NEXT OPTIONS ['nvd', 'rhn', 'ntq']
# nvd
# qnr nvd seen: ['cmg', 'bvb', 'xhk', 'jqt', 'nvd']
# Start: qnr: nvd... NEXT OPTIONS ['qnr', 'pzl', 'lhk']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: lsr; first edge lsr-frs
# lsr frs seen: ['frs']
# Start: lsr: frs... NEXT OPTIONS ['qnr', 'lhk', 'lsr', 'rsh']
# qnr
# lsr qnr seen: ['frs', 'qnr']
# Start: lsr: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# rzs
# lsr rzs seen: ['frs', 'qnr', 'rzs']
# Start: lsr: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# TRUETRUE
# TRUETRUE
# Working start node: lsr; first edge lsr-rsh
# lsr rsh seen: ['rsh']
# Start: lsr: rsh... NEXT OPTIONS ['rzs', 'frs', 'lsr', 'pzl']
# rzs
# lsr rzs seen: ['rsh', 'rzs']
# Start: lsr: rzs... NEXT OPTIONS ['qnr', 'cmg', 'lsr']
# TRUETRUE
# Working start node: lsr; first edge lsr-pzl
# lsr pzl seen: ['pzl']
# Start: lsr: pzl... NEXT OPTIONS ['nvd', 'hfx', 'lsr', 'rsh']
# nvd
# lsr nvd seen: ['pzl', 'nvd']
# Start: lsr: nvd... NEXT OPTIONS ['qnr', 'jqt', 'lhk', 'cmg']
# qnr
# lsr qnr seen: ['pzl', 'nvd', 'qnr']
# Start: lsr: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# rzs
# lsr rzs seen: ['pzl', 'nvd', 'qnr', 'rzs']
# Start: lsr: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: lsr; first edge lsr-rzs
# lsr rzs seen: ['rzs']
# Start: lsr: rzs... NEXT OPTIONS ['qnr', 'rsh', 'cmg', 'lsr']
# qnr
# lsr qnr seen: ['rzs', 'qnr']
# Start: lsr: qnr... NEXT OPTIONS ['frs', 'nvd', 'cmg']
# frs
# lsr frs seen: ['rzs', 'qnr', 'frs']
# Start: lsr: frs... NEXT OPTIONS ['lhk', 'lsr', 'rsh']
# TRUETRUE
# TRUETRUE
# Working start node: lsr; first edge lsr-lhk
# lsr lhk seen: ['lhk']
# Start: lsr: lhk... NEXT OPTIONS ['frs', 'lsr', 'nvd', 'cmg']
# frs
# lsr frs seen: ['lhk', 'frs']
# Start: lsr: frs... NEXT OPTIONS ['qnr', 'lsr', 'rsh']
# TRUETRUE
# Working start node: cmg; first edge cmg-bvb
# cmg bvb seen: ['bvb']
# Start: cmg: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx', 'cmg']
# xhk
# cmg xhk seen: ['bvb', 'xhk']
# Start: cmg: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# jqt
# cmg jqt seen: ['bvb', 'xhk', 'jqt']
# Start: cmg: jqt... NEXT OPTIONS ['nvd', 'rhn', 'ntq']
# nvd
# cmg nvd seen: ['bvb', 'xhk', 'jqt', 'nvd']
# Start: cmg: nvd... NEXT OPTIONS ['qnr', 'pzl', 'lhk', 'cmg']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: cmg; first edge cmg-nvd
# cmg nvd seen: ['nvd']
# Start: cmg: nvd... NEXT OPTIONS ['qnr', 'jqt', 'pzl', 'lhk', 'cmg']
# qnr
# cmg qnr seen: ['nvd', 'qnr']
# Start: cmg: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# TRUETRUE
# Working start node: cmg; first edge cmg-qnr
# cmg qnr seen: ['qnr']
# Start: cmg: qnr... NEXT OPTIONS ['rzs', 'frs', 'nvd', 'cmg']
# rzs
# cmg rzs seen: ['qnr', 'rzs']
# Start: cmg: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# TRUETRUE
# Working start node: cmg; first edge cmg-rzs
# cmg rzs seen: ['rzs']
# Start: cmg: rzs... NEXT OPTIONS ['qnr', 'rsh', 'cmg', 'lsr']
# qnr
# cmg qnr seen: ['rzs', 'qnr']
# Start: cmg: qnr... NEXT OPTIONS ['frs', 'nvd', 'cmg']
# TRUETRUE
# Working start node: cmg; first edge cmg-lhk
# cmg lhk seen: ['lhk']
# Start: cmg: lhk... NEXT OPTIONS ['frs', 'lsr', 'nvd', 'cmg']
# frs
# cmg frs seen: ['lhk', 'frs']
# Start: cmg: frs... NEXT OPTIONS ['qnr', 'lsr', 'rsh']
# qnr
# cmg qnr seen: ['lhk', 'frs', 'qnr']
# Start: cmg: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# TRUETRUE
# TRUETRUE
# Working start node: rsh; first edge rsh-rzs
# rsh rzs seen: ['rzs']
# Start: rsh: rzs... NEXT OPTIONS ['qnr', 'rsh', 'cmg', 'lsr']
# qnr
# rsh qnr seen: ['rzs', 'qnr']
# Start: rsh: qnr... NEXT OPTIONS ['frs', 'nvd', 'cmg']
# frs
# rsh frs seen: ['rzs', 'qnr', 'frs']
# Start: rsh: frs... NEXT OPTIONS ['lhk', 'lsr', 'rsh']
# TRUETRUE
# TRUETRUE
# Working start node: rsh; first edge rsh-frs
# rsh frs seen: ['frs']
# Start: rsh: frs... NEXT OPTIONS ['qnr', 'lhk', 'lsr', 'rsh']
# qnr
# rsh qnr seen: ['frs', 'qnr']
# Start: rsh: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# rzs
# rsh rzs seen: ['frs', 'qnr', 'rzs']
# Start: rsh: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# TRUETRUE
# TRUETRUE
# Working start node: rsh; first edge rsh-lsr
# rsh lsr seen: ['lsr']
# Start: rsh: lsr... NEXT OPTIONS ['frs', 'rsh', 'pzl', 'rzs', 'lhk']
# frs
# rsh frs seen: ['lsr', 'frs']
# Start: rsh: frs... NEXT OPTIONS ['qnr', 'lhk', 'rsh']
# TRUETRUE
# Working start node: rsh; first edge rsh-pzl
# rsh pzl seen: ['pzl']
# Start: rsh: pzl... NEXT OPTIONS ['nvd', 'hfx', 'lsr', 'rsh']
# nvd
# rsh nvd seen: ['pzl', 'nvd']
# Start: rsh: nvd... NEXT OPTIONS ['qnr', 'jqt', 'lhk', 'cmg']
# qnr
# rsh qnr seen: ['pzl', 'nvd', 'qnr']
# Start: rsh: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# rzs
# rsh rzs seen: ['pzl', 'nvd', 'qnr', 'rzs']
# Start: rsh: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: ntq; first edge ntq-xhk
# ntq xhk seen: ['xhk']
# Start: ntq: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn', 'hfx']
# bvb
# ntq bvb seen: ['xhk', 'bvb']
# Start: ntq: bvb... NEXT OPTIONS ['ntq', 'rhn', 'hfx', 'cmg']
# TRUETRUE
# Working start node: ntq; first edge ntq-bvb
# ntq bvb seen: ['bvb']
# Start: ntq: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx', 'cmg']
# xhk
# ntq xhk seen: ['bvb', 'xhk']
# Start: ntq: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# TRUETRUE
# Working start node: ntq; first edge ntq-hfx
# ntq hfx seen: ['hfx']
# Start: ntq: hfx... NEXT OPTIONS ['xhk', 'bvb', 'ntq', 'rhn', 'pzl']
# xhk
# ntq xhk seen: ['hfx', 'xhk']
# Start: ntq: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn']
# TRUETRUE
# Working start node: ntq; first edge ntq-jqt
# ntq jqt seen: ['jqt']
# Start: ntq: jqt... NEXT OPTIONS ['xhk', 'nvd', 'rhn', 'ntq']
# xhk
# ntq xhk seen: ['jqt', 'xhk']
# Start: ntq: xhk... NEXT OPTIONS ['bvb', 'ntq', 'rhn', 'hfx']
# TRUETRUE
# Working start node: frs; first edge frs-qnr
# frs qnr seen: ['qnr']
# Start: frs: qnr... NEXT OPTIONS ['rzs', 'frs', 'nvd', 'cmg']
# rzs
# frs rzs seen: ['qnr', 'rzs']
# Start: frs: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# frs rsh seen: ['qnr', 'rzs', 'rsh']
# Start: frs: rsh... NEXT OPTIONS ['frs', 'lsr', 'pzl']
# TRUETRUE
# TRUETRUE
# Working start node: frs; first edge frs-lhk
# frs lhk seen: ['lhk']
# Start: frs: lhk... NEXT OPTIONS ['frs', 'lsr', 'nvd', 'cmg']
# Back to start, not a bridge
# Working start node: frs; first edge frs-lsr
# frs lsr seen: ['lsr']
# Start: frs: lsr... NEXT OPTIONS ['frs', 'rsh', 'pzl', 'rzs', 'lhk']
# Back to start, not a bridge
# Working start node: frs; first edge frs-rsh
# frs rsh seen: ['rsh']
# Start: frs: rsh... NEXT OPTIONS ['rzs', 'frs', 'lsr', 'pzl']
# rzs
# frs rzs seen: ['rsh', 'rzs']
# Start: frs: rzs... NEXT OPTIONS ['qnr', 'cmg', 'lsr']
# qnr
# frs qnr seen: ['rsh', 'rzs', 'qnr']
# Start: frs: qnr... NEXT OPTIONS ['frs', 'nvd', 'cmg']
# TRUETRUE
# TRUETRUE
# Working start node: bvb; first edge bvb-xhk
# bvb xhk seen: ['xhk']
# Start: bvb: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn', 'hfx']
# Back to start, not a bridge
# Working start node: bvb; first edge bvb-ntq
# bvb ntq seen: ['ntq']
# Start: bvb: ntq... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# xhk
# bvb xhk seen: ['ntq', 'xhk']
# Start: bvb: xhk... NEXT OPTIONS ['bvb', 'jqt', 'rhn', 'hfx']
# TRUETRUE
# Working start node: bvb; first edge bvb-rhn
# bvb rhn seen: ['rhn']
# Start: bvb: rhn... NEXT OPTIONS ['xhk', 'bvb', 'hfx', 'jqt']
# xhk
# bvb xhk seen: ['rhn', 'xhk']
# Start: bvb: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'hfx']
# TRUETRUE
# Working start node: bvb; first edge bvb-hfx
# bvb hfx seen: ['hfx']
# Start: bvb: hfx... NEXT OPTIONS ['xhk', 'bvb', 'ntq', 'rhn', 'pzl']
# xhk
# bvb xhk seen: ['hfx', 'xhk']
# Start: bvb: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn']
# TRUETRUE
# Working start node: bvb; first edge bvb-cmg
# bvb cmg seen: ['cmg']
# Start: bvb: cmg... NEXT OPTIONS ['bvb', 'nvd', 'qnr', 'rzs', 'lhk']
# Back to start, not a bridge
# Working start node: lhk; first edge lhk-frs
# lhk frs seen: ['frs']
# Start: lhk: frs... NEXT OPTIONS ['qnr', 'lhk', 'lsr', 'rsh']
# qnr
# lhk qnr seen: ['frs', 'qnr']
# Start: lhk: qnr... NEXT OPTIONS ['rzs', 'nvd', 'cmg']
# rzs
# lhk rzs seen: ['frs', 'qnr', 'rzs']
# Start: lhk: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# lhk rsh seen: ['frs', 'qnr', 'rzs', 'rsh']
# Start: lhk: rsh... NEXT OPTIONS ['lsr', 'pzl']
# lsr
# lhk lsr seen: ['frs', 'qnr', 'rzs', 'rsh', 'lsr']
# Start: lhk: lsr... NEXT OPTIONS ['pzl', 'lhk']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: lhk; first edge lhk-lsr
# lhk lsr seen: ['lsr']
# Start: lhk: lsr... NEXT OPTIONS ['frs', 'rsh', 'pzl', 'rzs', 'lhk']
# frs
# lhk frs seen: ['lsr', 'frs']
# Start: lhk: frs... NEXT OPTIONS ['qnr', 'lhk', 'rsh']
# TRUETRUE
# Working start node: lhk; first edge lhk-nvd
# lhk nvd seen: ['nvd']
# Start: lhk: nvd... NEXT OPTIONS ['qnr', 'jqt', 'pzl', 'lhk', 'cmg']
# qnr
# lhk qnr seen: ['nvd', 'qnr']
# Start: lhk: qnr... NEXT OPTIONS ['rzs', 'frs', 'cmg']
# rzs
# lhk rzs seen: ['nvd', 'qnr', 'rzs']
# Start: lhk: rzs... NEXT OPTIONS ['rsh', 'cmg', 'lsr']
# rsh
# lhk rsh seen: ['nvd', 'qnr', 'rzs', 'rsh']
# Start: lhk: rsh... NEXT OPTIONS ['frs', 'lsr', 'pzl']
# frs
# lhk frs seen: ['nvd', 'qnr', 'rzs', 'rsh', 'frs']
# Start: lhk: frs... NEXT OPTIONS ['lhk', 'lsr']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: lhk; first edge lhk-cmg
# lhk cmg seen: ['cmg']
# Start: lhk: cmg... NEXT OPTIONS ['bvb', 'nvd', 'qnr', 'rzs', 'lhk']
# bvb
# lhk bvb seen: ['cmg', 'bvb']
# Start: lhk: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx']
# xhk
# lhk xhk seen: ['cmg', 'bvb', 'xhk']
# Start: lhk: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# jqt
# lhk jqt seen: ['cmg', 'bvb', 'xhk', 'jqt']
# Start: lhk: jqt... NEXT OPTIONS ['nvd', 'rhn', 'ntq']
# nvd
# lhk nvd seen: ['cmg', 'bvb', 'xhk', 'jqt', 'nvd']
# Start: lhk: nvd... NEXT OPTIONS ['qnr', 'pzl', 'lhk']
# TRUETRUE
# TRUETRUE
# TRUETRUE
# TRUETRUE
# Working start node: rhn; first edge rhn-xhk
# rhn xhk seen: ['xhk']
# Start: rhn: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn', 'hfx']
# bvb
# rhn bvb seen: ['xhk', 'bvb']
# Start: rhn: bvb... NEXT OPTIONS ['ntq', 'rhn', 'hfx', 'cmg']
# TRUETRUE
# Working start node: rhn; first edge rhn-bvb
# rhn bvb seen: ['bvb']
# Start: rhn: bvb... NEXT OPTIONS ['xhk', 'ntq', 'rhn', 'hfx', 'cmg']
# xhk
# rhn xhk seen: ['bvb', 'xhk']
# Start: rhn: xhk... NEXT OPTIONS ['jqt', 'ntq', 'rhn', 'hfx']
# TRUETRUE
# Working start node: rhn; first edge rhn-hfx
# rhn hfx seen: ['hfx']
# Start: rhn: hfx... NEXT OPTIONS ['xhk', 'bvb', 'ntq', 'rhn', 'pzl']
# xhk
# rhn xhk seen: ['hfx', 'xhk']
# Start: rhn: xhk... NEXT OPTIONS ['bvb', 'jqt', 'ntq', 'rhn']
# TRUETRUE
# Working start node: rhn; first edge rhn-jqt
# rhn jqt seen: ['jqt']
# Start: rhn: jqt... NEXT OPTIONS ['xhk', 'nvd', 'rhn', 'ntq']
# xhk
# rhn xhk seen: ['jqt', 'xhk']
# Start: rhn: xhk... NEXT OPTIONS ['bvb', 'ntq', 'rhn', 'hfx']
# TRUETRUE

# %%
bridges
# Out:
# [('hfx', 'pzl'), ('nvd', 'jqt')]

# %%
eee.sort_values().head(10)

# %%
es = pd.Series(ecc_sum)
es.sort_values().head(5)

# %%
sorted(ecc_sum.items())

# %%
pgraph = pydot.Dot(graph_type='graph')

# %%
for n1,n2 in g.edges:
    print(n1,n2)
    pgraph.add_edge(pydot.Edge(n1,n2))

# %%
pgraph.write_png('graph25.png')
